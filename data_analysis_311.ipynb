# %%
# %%time
import numpy as np
import datashader as ds, datashader.transfer_functions as tf
import dask.dataframe as dd
import holoviews as hv, pandas as pd, colorcet as cc
from holoviews.element.tiles import EsriImagery
from holoviews.operation.datashader import datashade
hv.extension('bokeh')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# CPU times: total: 31.2 ms
# Wall time: 80.7 ms

# %% [markdown]
# ## Read in Data

# %%
service_requests_old = pd.read_csv("./Citizen_Connect_Open_Public_Works_Service_Requests.csv")
print(service_requests_old.shape)

# Downloaded on march 19th 2024
new_service_requests = pd.read_csv("./Citizen_Connect_Open_Public_Works_Service_Requests_20240319.csv")
attributes = new_service_requests.columns
# print(attributes)
# Out:
# (12051, 58)

# %% [markdown]
# ## Data Parsing
# #### Retrived data is parsed into a service_request dictionary for easy access
# #### service_requests[category]

# %%
service_requests = dict()
parsed_attributes = dict()
attribute_set = set()
for attr in attributes:
    lowercase = attr.lower()
    lowercase = lowercase.replace(' ', '_')
    # print(f"{attr} : {lowercase}")
    attribute_set.add(lowercase)
    parsed_attributes[attr] = lowercase
    service_requests[lowercase] = new_service_requests[attr]

parsed_attributes


new_service_requests.rename(columns=parsed_attributes, inplace=True)
display(new_service_requests)
# Out:
#                  address1 address2 address3 area                   category  \
# 0              AUTUMN AVE      NaN      NaN  NaN  Environmental Maintenance
# 1             0 KIRBY PKY      NaN      NaN  NaN                Maintenance
# 2           3645 MIAMI CV      NaN      NaN  NaN         Inspection-Vehicle
# 3          4035 TRUMAN RD      NaN      NaN  NaN         Inspection-Vehicle
# 4        1077 VINEWOOD LN      NaN      NaN    D                     Others
# ...                   ...      ...      ...  ...                        ...
# 12107      312 ANGELUS ST      NaN      NaN    B                     Others
# 12108  460 E MCLEMORE AVE      NaN      NaN  NaN                     Others
# 12109       4565 VERNE RD      NaN      NaN    C              Miscellaneous
# 12110    481 ELLSWORTH ST      NaN      NaN    B  Environmental Maintenance
# 12111     4230 ARGONNE ST      NaN      NaN    A              Miscellaneous
#
#            ce_category     city close_date collection_day  created_by  ...  \
# 0                  NaN  MEMPHIS        NaN            NaN    460101.0  ...
# 1                  NaN  MEMPHIS        NaN            NaN    460101.0  ...
# 2                  NaN  MEMPHIS        NaN            NaN         NaN  ...
# 3                  NaN  MEMPHIS        NaN            NaN         NaN  ...
# 4                  NaN  MEMPHIS        NaN              5      3735.0  ...
# ...                ...      ...        ...            ...         ...  ...
# 12107              NaN  MEMPHIS        NaN              5    460101.0  ...
# 12108              NaN  MEMPHIS        NaN            NaN    460101.0  ...
# 12109  NOT-CATEGORIZED  MEMPHIS        NaN              1    460101.0  ...
# 12110              NaN  MEMPHIS        NaN              4    460101.0  ...
# 12111            COURT  MEMPHIS        NaN              4    460101.0  ...
#
#       memphis_3.0_planning_districts city_council_districts  \
# 0                                9.0                    4.0
# 1                                4.0                    2.0
# 2                                5.0                    5.0
# 3                                6.0                    7.0
# 4                               13.0                    6.0
# ...                              ...                    ...
# 12107                            8.0                    4.0
# 12108                           14.0                    6.0
# 12109                            9.0                    5.0
# 12110                            9.0                    4.0
# 12111                            1.0                    7.0
#
#       city_council_super_districts  memphis_3.0_focus_anchors_buffers  \
# 0                              2.0                                NaN
# 1                              2.0                                NaN
# 2                              1.0                                NaN
# 3                              2.0                                NaN
# 4                              1.0                                NaN
# ...                            ...                                ...
# 12107                          2.0                                NaN
# 12108                          1.0                                2.0
# 12109                          2.0                                NaN
# 12110                          2.0                                NaN
# 12111                          1.0                                NaN
#
#       community_neighborhoods_boundaries community_neighborhoods_boundaries_1  \
# 0                                   18.0                                  7.0
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 12107                               19.0                                  NaN
# 12108                                9.0                                  6.0
# 12109                                NaN                                  NaN
# 12110                               21.0                                  NaN
# 12111                               12.0                                  4.0
#
#       community_neighborhoods_boundaries_2  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 12107                                  NaN
# 12108                                  NaN
# 12109                                  NaN
# 12110                                  4.0
# 12111                                  NaN
#
#        council_district_boundaries_dec_2022  \
# 0                                       5.0
# 1                                       2.0
# 2                                       4.0
# 3                                       7.0
# 4                                       6.0
# ...                                     ...
# 12107                                   5.0
# 12108                                   4.0
# 12109                                   5.0
# 12110                                   5.0
# 12111                                   7.0
#
#        council_super_district_boundaries_dec_2022  \
# 0                                             2.0
# 1                                             2.0
# 2                                             1.0
# 3                                             2.0
# 4                                             1.0
# ...                                           ...
# 12107                                         2.0
# 12108                                         1.0
# 12109                                         2.0
# 12110                                         2.0
# 12111                                         1.0
#
#       memphis_police_department_stations
# 0                                    9.0
# 1                                    5.0
# 2                                    5.0
# 3                                    9.0
# 4                                    7.0
# ...                                  ...
# 12107                                4.0
# 12108                                4.0
# 12109                                5.0
# 12110                                9.0
# 12111                                3.0
#
# [12112 rows x 59 columns]

# %% [markdown]
# ## Tabulate functions

# %%
def tabulate(attribute_set, new_service_requests):
  for attr in attribute_set:
    
    freq_table = new_service_requests[attr].value_counts()
    percentages = new_service_requests[attr].value_counts(normalize=True) * 100
    newdf = pd.DataFrame({'Counts' : freq_table, 'Percentages': percentages})
    
    total_count = sum(newdf['Counts'])
    display(newdf)
    
    print(f'Total instances: {total_count}')
    

def tab_single(attribute, table):
  freq_table = table[attribute].value_counts()
  percentages = table[attribute].value_counts(normalize=True) * 100
  newdf = pd.DataFrame({'Counts': freq_table, 'Percentages' : percentages})
  total_count = sum(newdf['Counts'])
  display(newdf)
    
  print(f'Total instances: {total_count}')

# Uncomment to tabulate service_request data
# tabulate(attribute_set, new_service_requests)

# %%
tab_single('area', new_service_requests)
# Out:
#       Counts  Percentages
# area
# C       1926    24.108149
# A       1832    22.931531
# D       1700    21.279259
# B       1362    17.048442
# E       1049    13.130555
# F        114     1.426962
# c          4     0.050069
# b          1     0.012517
# 3          1     0.012517
# Total instances: 7989

# %% [markdown]
# ## Formalizing Data

# %%
#Area Column
new_service_requests['area'].replace({'c':'C', 'b':'B', '3':'A'}, inplace=True)

#Collection Day
new_service_requests['collection_day'].replace({'1':'Monday', '2':'Tuesday', '3':'Wednesday', '4':'Thursday', '5':'Friday', 'F': 'Friday'}, inplace=True)

#Department
new_service_requests['department'].replace({'ENVIRONMENTAL MAINTENANCE':'Environmental Maintenance', 'STREET MAINTENANCE':'Street Maintenance', 'GROUNDS MAINTENANCE':'Grounds Maintenance', 'HEAVY EQUIPMENT SERVICES':'Heavy Equipment Services'}, inplace=True)
new_service_requests['department'].unique()
# Out:
# array(['Environmental Maintenance', 'Street Maintenance',
#        'Code Enforcement', 'CE Commercial', 'Grounds Maintenance',
#        'Solid Waste Management', 'Heavy Equipment Services',
#        'Storm Water', 'Drain Maintenance'], dtype=object)

# %%
categories = service_requests['category']


# sort the dataset by categories
# sorted_by_category = new_service_requests.sort_values(by="category", ascending=True)

# instances that are not properly categorized
# parsed_empty = new_service_requests[(new_service_requests['category'] == 'Miscellaneous') | (new_service_requests['category'] == 'Others')]
# display(parsed_empty)

#take out the instnaces that are not properly categorized from the dataset
# new_service_requests = new_service_requests[(new_service_requests['category'] != 'Miscellaneous') & (new_service_requests['category'] != 'Others')]
# display(new_service_requests)


# dismiss specific location markers 
dismiss_address = new_service_requests.drop(['address1', 'address2', 'address3', 'location_1_(address)', 'location_1', 'street_name', 'map_page', 'city', 'state'], axis=1)
# display(dismiss_address)
print(dismiss_address['category'].unique())


# disregard logged times and dates for now. 
dropped_dates = dismiss_address.drop(['creation_date', 'followup_date','close_date','next_open_task_date', 'last_modified_date','incident_resolved_date', 'last_update_date', 'reported_date' ], axis=1)

print(dropped_dates['category'].unique())
drop_names = dropped_dates.drop(['created_by_user', 'last_update_login', 'last_updated_by', 'created_by', 'owner_name'], axis=1)

drop_summaries = drop_names.drop(['resolution_summary', 'summary'], axis=1)

parsed_empty = drop_summaries[(drop_summaries['category'] == 'Miscellaneous') | (drop_summaries['category'] == 'Others')]

raw_data = drop_summaries[(new_service_requests['category'] != 'Miscellaneous') & (new_service_requests['category'] != 'Others')]

# display(parsed_empty)
# print(raw_data['city'].unique())
# print(parsed_empty['city'].unique())

# tab_single('area', raw_data)
# display(raw_data['category'].unique())
# display(raw_data['division'].unique())

# display(raw_data['department'].unique())
tabulate(raw_data.columns, raw_data)

# idk why there are 4 instnaces with CT addresses
# close = dismiss_address[dismiss_address['city'] == 'CORDOVA']
# display(close['creation_date'].sort_values())

# wtf = dropped_dates[dropped_dates['state'] == 'CT']

# display(wtf)
# Out:
# ['Environmental Maintenance' 'Maintenance' 'Inspection-Vehicle' 'Others'
#  'Miscellaneous' 'Maintenance-Potholes' 'Inspection-Junky Yard' 'Weeds'
#  'Inspection-Structures' 'Cart Maintenance' 'Garbage'
#  'Inspection- Storage' 'Recycle' 'Cleanup' 'Service' 'Billing'
#  'Inspection-Vacant Violation' 'Storm Water' 'Inspection- Recreational'
#  'Maintenance-Alley']
# ['Environmental Maintenance' 'Maintenance' 'Inspection-Vehicle' 'Others'
#  'Miscellaneous' 'Maintenance-Potholes' 'Inspection-Junky Yard' 'Weeds'
#  'Inspection-Structures' 'Cart Maintenance' 'Garbage'
#  'Inspection- Storage' 'Recycle' 'Cleanup' 'Service' 'Billing'
#  'Inspection-Vacant Violation' 'Storm Water' 'Inspection- Recreational'
#  'Maintenance-Alley']
#       Counts  Percentages
# area
# C       1467    23.528468
# A       1458    23.384122
# D       1395    22.373697
# B        957    15.348837
# E        925    14.835605
# F         33     0.529270
# Total instances: 6235
#                              Counts  Percentages
# category
# Inspection-Structures          2944    32.960143
# Inspection-Vehicle             1363    15.259740
# Weeds                          1053    11.789073
# Environmental Maintenance       970    10.859830
# Inspection-Junky Yard           947    10.602329
# Cart Maintenance                655     7.333184
# Garbage                         457     5.116435
# Billing                         147     1.645768
# Maintenance                     139     1.556202
# Maintenance-Potholes             73     0.817286
# Inspection- Storage              58     0.649351
# Recycle                          50     0.559785
# Cleanup                          31     0.347067
# Inspection-Vacant Violation      27     0.302284
# Service                          11     0.123153
# Inspection- Recreational          4     0.044783
# Storm Water                       2     0.022391
# Maintenance-Alley                 1     0.011196
# Total instances: 8932
#                  Counts  Percentages
# ce_category
# VIOLATION (NS)     2163    40.780543
# VIOLATION (S)      1874    35.331825
# COURT               441     8.314480
# NPA                 427     8.050528
# NOT-CATEGORIZED     206     3.883861
# CD                  183     3.450226
# SHELBY COUNTY         3     0.056561
# OTHER                 3     0.056561
# BOARD-UP              3     0.056561
# OPEN                  1     0.018854
# Total instances: 5304
#                 Counts  Percentages
# collection_day
# Wednesday         1515    24.294419
# Friday            1342    21.520205
# Thursday          1304    20.910840
# Tuesday           1052    16.869788
# Monday            1023    16.404747
# Total instances: 6236
#                            Counts  Percentages
# department
# Code Enforcement             5745    64.319301
# Solid Waste Management       1320    14.778325
# Environmental Maintenance     970    10.859830
# Grounds Maintenance           653     7.310793
# Street Maintenance            214     2.395880
# Heavy Equipment Services       15     0.167936
# Drain Maintenance              13     0.145544
# Storm Water                     2     0.022391
# Total instances: 8932
#           Counts  Percentages
# district
# 7.0         1395    23.316062
# 4.0         1332    22.263079
# 6.0         1131    18.903560
# 5.0          787    13.153936
# 3.0          619    10.345980
# 1.0          461     7.705165
# 2.0          258     4.312218
# Total instances: 5983
#                         Counts  Percentages
# division
# Public Works              7612    85.221675
# Solid Waste Management    1320    14.778325
# Total instances: 8932
#                                           Counts  Percentages
# group_name
# Community Enhancement                       5015    56.917490
# Memphis                                     1631    18.510952
# MEMPHIS                                      859     9.749177
# CITIZEN                                      384     4.358189
# Environmental Maintenance and Inspection     360     4.085802
# EMI Repair - New                             228     2.587674
# Public Works                                  96     1.089547
# MEM                                           92     1.044149
# Solid Waste Management                        51     0.578822
# MCSC-Duplicates                               46     0.522075
# Environmental Enforcement                     19     0.215640
# MCSC                                          12     0.136193
# CE- Commercial                                11     0.124844
# Convention Center                              2     0.022699
# Shelby County Mayor's Action Center            1     0.011349
# Police Services                                1     0.011349
# EMI Contractors Repair                         1     0.011349
# CE - Condemnation Admin office                 1     0.011349
# Engineering                                    1     0.011349
# Total instances: 8811
#              Counts  Percentages
# incident_id
# 0.0               4     0.045254
# 7064416.0         2     0.022627
# 7006374.0         2     0.022627
# 9024902.0         1     0.011313
# 8778510.0         1     0.011313
# ...             ...          ...
# 8753906.0         1     0.011313
# 9091904.0         1     0.011313
# 7053900.0         1     0.011313
# 7049805.0         1     0.011313
# 8728044.0         1     0.011313
#
# [8834 rows x 2 columns]
# Total instances: 8839
#                  Counts  Percentages
# incident_number
# 6413692               1     0.011196
# 3995438               1     0.011196
# 7060609               1     0.011196
# 6457448               1     0.011196
# 6397608               1     0.011196
# ...                 ...          ...
# 6069472               1     0.011196
# 6144300               1     0.011196
# 6480240               1     0.011196
# 7053900               1     0.011196
# 6118520               1     0.011196
#
# [8932 rows x 2 columns]
# Total instances: 8932
#                   Counts  Percentages
# incident_type_id
# 10409               2944    32.960143
# 10400               1363    15.259740
# 10693                970    10.859830
# 10395                947    10.602329
# 10205                400     4.478280
# 10547                399     4.467085
# 10431                370     4.142409
# 10204                249     2.787730
# 10441                206     2.306314
# 10430                160     1.791312
# 10747                122     1.365876
# 10442                106     1.186744
# 12750                 90     1.007613
# 10432                 87     0.974026
# 12747                 83     0.929243
# 10266                 73     0.817286
# 12748                 68     0.761308
# 10401                 58     0.649351
# 10435                 50     0.559785
# 10203                 27     0.302284
# 10711                 27     0.302284
# 17747                 21     0.235110
# 10448                 14     0.156740
# 10667                 14     0.156740
# 10587                 12     0.134348
# 10440                 11     0.123153
# 10439                 11     0.123153
# 10264                 10     0.111957
# 10527                  5     0.055979
# 10668                  5     0.055979
# 10748                  4     0.044783
# 12749                  4     0.044783
# 10567                  4     0.044783
# 10408                  4     0.044783
# 10488                  3     0.033587
# 10392                  3     0.033587
# 10712                  2     0.022391
# 10269                  2     0.022391
# 10268                  1     0.011196
# 10427                  1     0.011196
# 10429                  1     0.011196
# 10265                  1     0.011196
# Total instances: 8932
#                  Counts  Percentages
# number_of_tasks
# 2.0                1280    21.519839
# 3.0                 791    13.298588
# 5.0                 749    12.592468
# 0.0                 743    12.491594
# 4.0                 526     8.843309
# 6.0                 367     6.170141
# 7.0                 251     4.219906
# 1.0                 250     4.203093
# 8.0                 246     4.135844
# 9.0                 232     3.900471
# 10.0                170     2.858104
# 11.0                 88     1.479489
# 12.0                 62     1.042367
# 13.0                 46     0.773369
# 15.0                 35     0.588433
# 14.0                 35     0.588433
# 16.0                 24     0.403497
# 17.0                 18     0.302623
# 18.0                 11     0.184936
# 19.0                 11     0.184936
# 21.0                  5     0.084062
# 22.0                  3     0.050437
# 23.0                  2     0.033625
# 26.0                  1     0.016812
# 25.0                  1     0.016812
# 20.0                  1     0.016812
# Total instances: 5948
#                Counts  Percentages
# parcel_id
# 074090 00079       46     0.535506
# 059042  00011      14     0.162980
# 047073  00028      13     0.151339
# 047073  00027       6     0.069849
# 041034  00101       5     0.058207
# ...               ...          ...
# 078034  00019       1     0.011641
# 072041  00022       1     0.011641
# 053025  00029       1     0.011641
# 063016  00001       1     0.011641
# 060211  00002       1     0.011641
#
# [7724 rows x 2 columns]
# Total instances: 8590
#              Counts  Percentages
# postal_code
# 38016           140     2.105897
# 38109           127     1.910349
# 38115           123     1.850181
# 38119            93     1.398917
# 38018            86     1.293622
# ...             ...          ...
# 38108-2633        1     0.015042
# 38111-5129        1     0.015042
# 38104-5057        1     0.015042
# 38114-6416        1     0.015042
# 38109-7120        1     0.015042
#
# [4033 rows x 2 columns]
# Total instances: 6648
#                   Counts  Percentages
# request_priority
# Low                 5983    66.998880
# Medium              2615    29.283315
# High                 243     2.721165
# Emergency             89     0.996641
# Total instances: 8930
#                     Counts  Percentages
# request_status
# In Progress           4879    54.623824
# Open                  2767    30.978504
# Pending Litigation     863     9.661890
# Back to Department     243     2.720555
# Back to MCSC           180     2.015226
# Total instances: 8932
#                                     Counts  Percentages
# request_type
# CE-Substandard,Derelict Struc         2944    32.960143
# CE-Vehicle Violations                 1363    15.259740
# EMI-Cave In                            970    10.859830
# CE-Junky Yard                          947    10.602329
# CW-Weeds Vacant Lots                   400     4.478280
# CE-Weeds Occupied Property             399     4.467085
# SWM-Missed Bulk Trash                  370     4.142409
# CW-Weeds Vacant Houses                 249     2.787730
# SWM-Missing Cart                       206     2.306314
# SWM-Cart Repair                        160     1.791312
# PW (SM)-Street Cracking/Crumbling      122     1.365876
# SWM-New Start Garbage Request          106     1.186744
# SWM-Recycle Cart Repair                 90     1.007613
# SWM-Garbage Missed                      87     0.974026
# SWM-Missing Recycle Cart                83     0.929243
# PW (SM)-Potholes                        73     0.817286
# SWM-Recycle Cart Delivery               68     0.761308
# CE-Open Storage and Furnishin           58     0.649351
# SWM-Recycling Missed                    50     0.559785
# PW (HE)-Street Cleaning                 27     0.302284
# CE-Vacant Lot Code Violation            27     0.302284
# SWM-Contaminated Recycle Cart           21     0.235110
# SWM-Code Violation                      14     0.156740
# SWM-Dead Animal Collection              14     0.156740
# SWM-Cart Lease Application              12     0.134348
# SWM-Solid Waste Fees                    11     0.123153
# SWM-Service Quality                     11     0.123153
# PW (SM)-Street/Pavement Inspection      10     0.111957
# CW-Miscellaneous                         5     0.055979
# SWM-Carts Out After-hours                5     0.055979
# PW (SM)-Guardrails                       4     0.044783
# SWM-Recycle Cart Pickup                  4     0.044783
# SWM-Pick-Up Extra Cart                   4     0.044783
# CE-Recreational Vehicle Illeg            4     0.044783
# SWM-Switched Cart                        3     0.033587
# CE-Accumulation of Stagnant              3     0.033587
# PW (SW)-Storm Water                      2     0.022391
# PW (SM)-Trees in Street                  2     0.022391
# PW (SM)-Trees Trimming                   1     0.011196
# PW (SM)-Alley Debris                     1     0.011196
# SWM-Burnt Cart                           1     0.011196
# PW (SM)-Pot Hole in Alley                1     0.011196
# Total instances: 8932
#                  Counts  Percentages
# resolution_code
# VOYC               1226    20.864534
# FM-7                509     8.662355
# NPF11-1             403     6.858407
# NON-COMPLIANCE      398     6.773315
# CTCNT               384     6.535058
# ...                 ...          ...
# PWSMPHCTPCH           1     0.017018
# SO                    1     0.017018
# OCC-RI2-NP            1     0.017018
# OCC-RI1-WP            1     0.017018
# COM_PROPERTY          1     0.017018
#
# [90 rows x 2 columns]
# Total instances: 5876
#                                                     Counts  Percentages
# resolution_code_meaning
# V.O. Yard/Vehicle                                      871    17.479430
# No Progress Form 11 Complete                           787    15.793699
# Hearing missed - FORM 7                                499    10.014048
# Not in compliance                                      394     7.906883
# Keeps the file open in the system Keeping the s...     383     7.686133
# ...                                                    ...          ...
# Board And Secure Notified Contractor                     1     0.020068
# Order of condemnation Rehab inspection 1 ï¿½ No...       1     0.020068
# OCC Appeal to Repair                                     1     0.020068
# Order of condemnation Rehab inspection 2 ï¿½ No...       1     0.020068
# Commercial Court setting 1 - ?                           1     0.020068
#
# [61 rows x 2 columns]
# Total instances: 4983
#                      Counts  Percentages
# sr_creation_channel
# WEB                    7257    81.247201
# PHONE                  1672    18.719212
# Web                       3     0.033587
# Total instances: 8932
#               Counts  Percentages
# sub_district
# 5.0             1130    19.129846
# 2.0             1032    17.470797
# 4.0              990    16.759777
# 3.0              974    16.488911
# 1.0              750    12.696800
# 6.0              504     8.532250
# 7.0              452     7.651938
# 8.0               75     1.269680
# Total instances: 5907
#           Counts  Percentages
# swm_code
# C10         3666    66.922234
# C3           481     8.780577
# C11          321     5.859803
# C80          286     5.220884
# C10A         131     2.391384
# C10R          85     1.551661
# C2            82     1.496897
# C20           50     0.912742
# C32           48     0.876232
# C35           45     0.821468
# C70           42     0.766703
# C7            31     0.565900
# C31           29     0.529390
# C49           27     0.492881
# C17           22     0.401606
# C1            19     0.346842
# C13           17     0.310332
# C55           15     0.273823
# C80A          12     0.219058
# C15           10     0.182548
# C71            6     0.109529
# C44            6     0.109529
# C18            5     0.091274
# C12            5     0.091274
# C21            5     0.091274
# C27            4     0.073019
# C11A           4     0.073019
# C57            4     0.073019
# C19            4     0.073019
# C84            3     0.054765
# C5             3     0.054765
# C11R           2     0.036510
# C56            2     0.036510
# C58            1     0.018255
# C80R           1     0.018255
# C80B           1     0.018255
# C16            1     0.018255
# C10B           1     0.018255
# C14            1     0.018255
# Total instances: 5478
#               Counts  Percentages
# target_block
# 39.0             132     3.184560
# 40.0             114     2.750302
# 52.0              61     1.471653
# 152.0             61     1.471653
# 192.0             59     1.423402
# ...              ...          ...
# 87.0               1     0.024125
# 92.0               1     0.024125
# 84.0               1     0.024125
# 212.0              1     0.024125
# 171.0              1     0.024125
#
# [231 rows x 2 columns]
# Total instances: 4145
#       Counts  Percentages
# zone
# D3       583     9.348942
# A2       558     8.948044
# C2       551     8.835792
# A1       524     8.402822
# C1       490     7.857601
# C3       423     6.783194
# D1       411     6.590763
# D2       403     6.462476
# A3       374     5.997434
# B3       333     5.339962
# B2       325     5.211674
# E1       313     5.019243
# B1       300     4.810776
# E8       293     4.698525
# E2       286     4.586273
# F9        33     0.529185
# E3        32     0.513149
# c1         3     0.048108
# E6         1     0.016036
# Total instances: 6236
#                          Counts  Percentages
# shelby_county_zip_codes
# 9.0                         868     9.739677
# 6.0                         731     8.202424
# 17.0                        674     7.562837
# 13.0                        614     6.889587
# 8.0                         595     6.676391
# 10.0                        590     6.620287
# 23.0                        557     6.250000
# 20.0                        472     5.296230
# 7.0                         422     4.735189
# 24.0                        403     4.521993
# 15.0                        323     3.624327
# 11.0                        306     3.433573
# 14.0                        297     3.332585
# 16.0                        277     3.108169
# 4.0                         256     2.872531
# 28.0                        253     2.838869
# 34.0                        252     2.827648
# 18.0                        184     2.064632
# 31.0                        162     1.817774
# 1.0                         148     1.660682
# 22.0                        116     1.301616
# 27.0                        105     1.178187
# 5.0                          86     0.964991
# 19.0                         86     0.964991
# 21.0                         85     0.953770
# 3.0                          17     0.190754
# 29.0                         14     0.157092
# 33.0                          7     0.078546
# 30.0                          4     0.044883
# 26.0                          3     0.033662
# 12.0                          2     0.022442
# 2.0                           1     0.011221
# 35.0                          1     0.011221
# 36.0                          1     0.011221
# Total instances: 8912
#                                 Counts  Percentages
# memphis_3.0_planning_districts
# 14.0                              1145    12.898502
# 7.0                                846     9.530247
# 11.0                               833     9.383801
# 9.0                                800     9.012054
# 8.0                                691     7.784161
# 6.0                                687     7.739101
# 3.0                                684     7.705306
# 13.0                               620     6.984342
# 1.0                                554     6.240847
# 5.0                                519     5.846570
# 2.0                                455     5.125605
# 10.0                               373     4.201870
# 4.0                                345     3.886448
# 12.0                               325     3.661147
# Total instances: 8877
#                         Counts  Percentages
# city_council_districts
# 5.0                       1807    20.351391
# 7.0                       1732    19.506701
# 6.0                       1570    17.682171
# 4.0                       1254    14.123212
# 3.0                        984    11.082329
# 1.0                        807     9.088861
# 2.0                        725     8.165334
# Total instances: 8879
#                               Counts  Percentages
# city_council_super_districts
# 1.0                             5308    59.781507
# 2.0                             3571    40.218493
# Total instances: 8879
#                                    Counts  Percentages
# memphis_3.0_focus_anchors_buffers
# 5.0                                   128    37.869822
# 6.0                                    60    17.751479
# 4.0                                    51    15.088757
# 1.0                                    46    13.609467
# 3.0                                    40    11.834320
# 2.0                                    13     3.846154
# Total instances: 338
#                                     Counts  Percentages
# community_neighborhoods_boundaries
# 9.0                                   1289    21.740597
# 8.0                                   1019    17.186709
# 12.0                                   554     9.343903
# 43.0                                   413     6.965762
# 29.0                                   371     6.257379
# 1.0                                    301     5.076741
# 25.0                                   283     4.773149
# 19.0                                   257     4.334626
# 21.0                                   188     3.170855
# 40.0                                   186     3.137123
# 35.0                                   147     2.479339
# 16.0                                   139     2.344409
# 18.0                                   123     2.074549
# 7.0                                     76     1.281835
# 27.0                                    75     1.264969
# 41.0                                    70     1.180638
# 20.0                                    66     1.113173
# 6.0                                     61     1.028841
# 31.0                                    55     0.927644
# 36.0                                    54     0.910778
# 4.0                                     39     0.657784
# 37.0                                    34     0.573453
# 44.0                                    33     0.556586
# 24.0                                    27     0.455389
# 2.0                                     21     0.354191
# 32.0                                    20     0.337325
# 26.0                                    18     0.303593
# 5.0                                      7     0.118064
# 42.0                                     1     0.016866
# 34.0                                     1     0.016866
# 3.0                                      1     0.016866
# Total instances: 5929
#                                       Counts  Percentages
# community_neighborhoods_boundaries_1
# 2.0                                     1019    22.161809
# 4.0                                      554    12.048717
# 21.0                                     413     8.982166
# 12.0                                     371     8.068726
# 1.0                                      354     7.699000
# 18.0                                     289     6.285341
# 10.0                                     283     6.154850
# 13.0                                     203     4.414963
# 6.0                                      164     3.566768
# 8.0                                      159     3.458025
# 16.0                                     147     3.197042
# 7.0                                      123     2.675076
# 11.0                                      95     2.066116
# 5.0                                       86     1.870378
# 19.0                                      70     1.522401
# 15.0                                      68     1.478904
# 9.0                                       58     1.261418
# 14.0                                      56     1.217921
# 20.0                                      38     0.826446
# 22.0                                      33     0.717703
# 17.0                                      13     0.282732
# 3.0                                        2     0.043497
# Total instances: 4598
#                                       Counts  Percentages
# community_neighborhoods_boundaries_2
# 1.0                                      413    32.443048
# 7.0                                      358    28.122545
# 4.0                                      216    16.967793
# 3.0                                      148    11.626080
# 6.0                                       97     7.619796
# 2.0                                       21     1.649647
# 5.0                                       20     1.571092
# Total instances: 1273
#                                       Counts  Percentages
# council_district_boundaries_dec_2022
# 4.0                                     1952    21.991888
# 7.0                                     1701    19.164038
# 6.0                                     1635    18.420460
# 5.0                                     1322    14.894096
# 1.0                                      811     9.136999
# 3.0                                      805     9.069401
# 2.0                                      650     7.323119
# Total instances: 8876
#                                             Counts  Percentages
# council_super_district_boundaries_dec_2022
# 1.0                                           5276     59.44119
# 2.0                                           3600     40.55881
# Total instances: 8876
#                                     Counts  Percentages
# memphis_police_department_stations
# 4.0                                   1440    16.219869
# 9.0                                   1285    14.473981
# 5.0                                   1164    13.111061
# 1.0                                   1113    12.536607
# 3.0                                    978    11.015995
# 7.0                                    945    10.644289
# 2.0                                    928    10.452805
# 8.0                                    669     7.535481
# 6.0                                    356     4.009912
# Total instances: 8878

# %% [markdown]
# ## Formalizing data

# %%
# Entries that need to be fromalized:


new_classifier = {
    tuple(["Weeds", "Storm Water", "Recycle"]) : "Environmental Maintenance",
    tuple(["Maintenance", "Maintenance-Alley", "Cart Maintenance", "Maintenance-Potholes"]): "Infrastructure Maintenance",
    tuple(["Inspection-Vehicle", "Inspection-Junky Yard", "Inspection- Recreational", "Inspection-Vacant Violation", "Inspection-Structures", "Inspection- Storage"]): "Inspections",
    tuple(["Cleanup", "Service", "Billing", "Garbage"]): "Public Works"
} 

for t in new_classifier:
    for cat in t:
    
        raw_data['category'].replace(cat, new_classifier[t], inplace=True)

raw_data['category'].unique()
# Out:
# C:\Users\mcmah\AppData\Local\Temp\ipykernel_35940\2494698396.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_data['category'].replace(cat, new_classifier[t], inplace=True)
# array(['Environmental Maintenance', 'Infrastructure Maintenance',
#        'Inspections', 'Public Works'], dtype=object)

# %% [markdown]
# # Encode Values & Algorithm Tests

# %%
raw_data.dtypes
print(raw_data['category'].value_counts())
#print(sum(raw_data['category'].value_counts()))
# Out:
# category
# Inspections                   5343
# Environmental Maintenance     2075
# Infrastructure Maintenance     868
# Public Works                   646
# Name: count, dtype: int64

# %% [markdown]
# ### Encoding

# %%
# Encoding libraries
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

#Algorithm libraries
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB


# Statistical Data 
from sklearn.metrics import classification_report

from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

categorical_features = [col for col in raw_data.columns if raw_data[col].dtype == 'object' and col != 'category']
print(categorical_features)

one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot", one_hot, categorical_features)], remainder="passthrough")

X = raw_data.drop('category', axis=1)
y = raw_data['category']

transformed_X = transformer.fit_transform(X)
print(transformed_X.shape)
transformed_X = pd.DataFrame(transformed_X)
# transformed_X.head()

dummies = pd.get_dummies(raw_data[categorical_features])
display(dummies)

display(parsed_empty)
empty_transformed = pd.get_dummies(parsed_empty[categorical_features])
display(empty_transformed)
# Out:
# ['area', 'ce_category', 'collection_day', 'department', 'division', 'group_name', 'parcel_id', 'postal_code', 'request_priority', 'request_status', 'request_type', 'resolution_code', 'resolution_code_meaning', 'sr_creation_channel', 'swm_code', 'zone']
# (8932, 12099)
#        area_A  area_B  area_C  area_D  area_E  area_F  ce_category_BOARD-UP  \
# 0       False   False   False   False   False   False                 False
# 1       False   False   False   False   False   False                 False
# 2       False   False   False   False   False   False                 False
# 3       False   False   False   False   False   False                 False
# 6       False   False    True   False   False   False                 False
# ...       ...     ...     ...     ...     ...     ...                   ...
# 12101   False   False   False    True   False   False                 False
# 12102   False   False   False    True   False   False                 False
# 12105   False   False   False    True   False   False                 False
# 12106   False   False   False    True   False   False                 False
# 12110   False    True   False   False   False   False                 False
#
#        ce_category_CD  ce_category_COURT  ce_category_NOT-CATEGORIZED  ...  \
# 0               False              False                        False  ...
# 1               False              False                        False  ...
# 2               False              False                        False  ...
# 3               False              False                        False  ...
# 6               False              False                        False  ...
# ...               ...                ...                          ...  ...
# 12101           False              False                        False  ...
# 12102           False               True                        False  ...
# 12105           False              False                        False  ...
# 12106           False               True                        False  ...
# 12110           False              False                        False  ...
#
#        zone_D1  zone_D2  zone_D3  zone_E1  zone_E2  zone_E3  zone_E6  zone_E8  \
# 0        False    False    False    False    False    False    False    False
# 1        False    False    False    False    False    False    False    False
# 2        False    False    False    False    False    False    False    False
# 3        False    False    False    False    False    False    False    False
# 6        False    False    False    False    False    False    False    False
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 12101    False    False     True    False    False    False    False    False
# 12102     True    False    False    False    False    False    False    False
# 12105    False    False     True    False    False    False    False    False
# 12106    False    False     True    False    False    False    False    False
# 12110    False    False    False    False    False    False    False    False
#
#        zone_F9  zone_c1
# 0        False    False
# 1        False    False
# 2        False    False
# 3        False    False
# 6        False    False
# ...        ...      ...
# 12101    False    False
# 12102    False    False
# 12105    False    False
# 12106    False    False
# 12110    False    False
#
# [8932 rows x 12070 columns]
#       area       category      ce_category collection_day  \
# 4        D         Others              NaN         Friday
# 5      NaN  Miscellaneous   VIOLATION (NS)            NaN
# 7        A         Others              NaN        Tuesday
# 8      NaN  Miscellaneous  NOT-CATEGORIZED            NaN
# 9      NaN  Miscellaneous  NOT-CATEGORIZED            NaN
# ...    ...            ...              ...            ...
# 12104  NaN  Miscellaneous            COURT            NaN
# 12107    B         Others              NaN         Friday
# 12108  NaN         Others              NaN            NaN
# 12109    C  Miscellaneous  NOT-CATEGORIZED         Monday
# 12111    A  Miscellaneous            COURT       Thursday
#
#                       department  district      division  \
# 4      Environmental Maintenance       6.0  Public Works
# 5               Code Enforcement       3.0  Public Works
# 7      Environmental Maintenance       1.0  Public Works
# 8                  CE Commercial       6.0  Public Works
# 9                  CE Commercial       6.0  Public Works
# ...                          ...       ...           ...
# 12104           Code Enforcement       6.0  Public Works
# 12107  Environmental Maintenance       5.0  Public Works
# 12108  Environmental Maintenance       6.0  Public Works
# 12109           Code Enforcement       4.0  Public Works
# 12111           Code Enforcement       7.0  Public Works
#
#                   group_name  incident_id  incident_number  ...  \
# 4           EMI Repair - New    7286634.0          4709796  ...
# 5            MCSC-Duplicates    8134626.0          5529536  ...
# 7           EMI Repair - New    8556878.0          5948520  ...
# 8      Community Enhancement    8842800.0          6232570  ...
# 9             CE- Commercial    8901604.0          6291080  ...
# ...                      ...          ...              ...  ...
# 12104  Community Enhancement    8669888.0          6060622  ...
# 12107       EMI Repair - New    8767432.0          6157718  ...
# 12108       EMI Repair - New    8994878.0          6383806  ...
# 12109  Community Enhancement    9105482.0          6492192  ...
# 12111  Community Enhancement    8759152.0          6149508  ...
#
#        memphis_3.0_planning_districts  city_council_districts  \
# 4                                13.0                     6.0
# 5                                12.0                     3.0
# 7                                 2.0                     1.0
# 8                                14.0                     6.0
# 9                                 8.0                     6.0
# ...                               ...                     ...
# 12104                             8.0                     6.0
# 12107                             8.0                     4.0
# 12108                            14.0                     6.0
# 12109                             9.0                     5.0
# 12111                             1.0                     7.0
#
#       city_council_super_districts memphis_3.0_focus_anchors_buffers  \
# 4                              1.0                               NaN
# 5                              1.0                               NaN
# 7                              2.0                               NaN
# 8                              1.0                               2.0
# 9                              1.0                               NaN
# ...                            ...                               ...
# 12104                          1.0                               NaN
# 12107                          2.0                               NaN
# 12108                          1.0                               2.0
# 12109                          2.0                               NaN
# 12111                          1.0                               NaN
#
#       community_neighborhoods_boundaries community_neighborhoods_boundaries_1  \
# 4                                    NaN                                  NaN
# 5                                   43.0                                 21.0
# 7                                    NaN                                  NaN
# 8                                    9.0                                  6.0
# 9                                    9.0                                  NaN
# ...                                  ...                                  ...
# 12104                                3.0                                  NaN
# 12107                               19.0                                  NaN
# 12108                                9.0                                  6.0
# 12109                                NaN                                  NaN
# 12111                               12.0                                  4.0
#
#       community_neighborhoods_boundaries_2  \
# 4                                      NaN
# 5                                      NaN
# 7                                      NaN
# 8                                      5.0
# 9                                      NaN
# ...                                    ...
# 12104                                  NaN
# 12107                                  NaN
# 12108                                  NaN
# 12109                                  NaN
# 12111                                  NaN
#
#       council_district_boundaries_dec_2022  \
# 4                                      6.0
# 5                                      3.0
# 7                                      1.0
# 8                                      6.0
# 9                                      6.0
# ...                                    ...
# 12104                                  7.0
# 12107                                  5.0
# 12108                                  4.0
# 12109                                  5.0
# 12111                                  7.0
#
#       council_super_district_boundaries_dec_2022  \
# 4                                            1.0
# 5                                            1.0
# 7                                            2.0
# 8                                            1.0
# 9                                            1.0
# ...                                          ...
# 12104                                        1.0
# 12107                                        2.0
# 12108                                        1.0
# 12109                                        2.0
# 12111                                        1.0
#
#       memphis_police_department_stations
# 4                                    7.0
# 5                                    7.0
# 7                                    3.0
# 8                                    4.0
# 9                                    4.0
# ...                                  ...
# 12104                                6.0
# 12107                                4.0
# 12108                                4.0
# 12109                                5.0
# 12111                                3.0
#
# [3180 rows x 35 columns]
#        area_A  area_B  area_C  area_D  area_E  area_F  ce_category_BOARD-UP  \
# 4       False   False   False    True   False   False                 False
# 5       False   False   False   False   False   False                 False
# 7        True   False   False   False   False   False                 False
# 8       False   False   False   False   False   False                 False
# 9       False   False   False   False   False   False                 False
# ...       ...     ...     ...     ...     ...     ...                   ...
# 12104   False   False   False   False   False   False                 False
# 12107   False    True   False   False   False   False                 False
# 12108   False   False   False   False   False   False                 False
# 12109   False   False    True   False   False   False                 False
# 12111    True   False   False   False   False   False                 False
#
#        ce_category_CD  ce_category_COURT  ce_category_NOT-CATEGORIZED  ...  \
# 4               False              False                        False  ...
# 5               False              False                        False  ...
# 7               False              False                        False  ...
# 8               False              False                         True  ...
# 9               False              False                         True  ...
# ...               ...                ...                          ...  ...
# 12104           False               True                        False  ...
# 12107           False              False                        False  ...
# 12108           False              False                        False  ...
# 12109           False              False                         True  ...
# 12111           False               True                        False  ...
#
#        zone_D2  zone_D3  zone_E1  zone_E2  zone_E6  zone_E8  zone_F1  zone_F9  \
# 4        False    False    False    False    False    False    False    False
# 5        False    False    False    False    False    False    False    False
# 7        False    False    False    False    False    False    False    False
# 8        False    False    False    False    False    False    False    False
# 9        False    False    False    False    False    False    False    False
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 12104    False    False    False    False    False    False    False    False
# 12107    False    False    False    False    False    False    False    False
# 12108    False    False    False    False    False    False    False    False
# 12109    False    False    False    False    False    False    False    False
# 12111    False    False    False    False    False    False    False    False
#
#        zone_b5  zone_c1
# 4        False    False
# 5        False    False
# 7        False    False
# 8        False    False
# 9        False    False
# ...        ...      ...
# 12104    False    False
# 12107    False    False
# 12108    False    False
# 12109    False    False
# 12111    False    False
#
# [3180 rows x 4736 columns]

# %% [markdown]
# # Naive Bayes

# %%
# genrate seed
np.random.seed(42)

# make the data
y = raw_data['category']

X_train, X_test, y_train, y_test = train_test_split(dummies, y, test_size=0.3, random_state=0)

# print(X_train)

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

y_pred=nb_model.predict(X_test)

print(classification_report(y_test, y_pred))


nb_model.score(X_test, y_test)
print(confusion_matrix(y_test, y_pred))
# Out:
#                             precision    recall  f1-score   support
#
#  Environmental Maintenance       0.95      0.99      0.97       625
# Infrastructure Maintenance       1.00      0.98      0.99       267
#                Inspections       1.00      0.98      0.99      1617
#               Public Works       0.95      1.00      0.97       171
#
#                   accuracy                           0.98      2680
#                  macro avg       0.97      0.99      0.98      2680
#               weighted avg       0.98      0.98      0.98      2680
#
# [[ 617    1    5    2]
#  [   0  261    0    6]
#  [  32    0 1584    1]
#  [   0    0    0  171]]

# %%
# new_classifier = {
#     "Environmental Maintenance": ["Weeds", "Storm Water", "Recycle"],
#     "Infrastructure Maintenance": ["Maintenance", "Maintenance-Alley", "Maintenance-Cart", "Maintenance-Potholes"],
#     "Inspections": ["Inspection-Vehicle", "Inspection-Junky_Yard", "Inspection-Recreational", "Inspection-Vacant Violation", "Inspection-Structures"],
#     "Public Works": ["Cleanup", "Service", "Billing"]
# } 

# y = new_classifier

# X_train, X_test, y_train, y_test = train_test_split(dummies, y, test_size=0.3, random_state=0)

# # print(X_train)

# nb_model = GaussianNB()
# nb_model.fit(X_train, y_train)

# y_pred=nb_model.predict(X_test)

# print(classification_report(y_test, y_pred))

# nb_model.score(X_test, y_test)

from sklearn import tree
Y = raw_data['category']
X = transformed_X

clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth=3)
clf = clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
clf.score(X_test, y_test)

# import pydotplus 
# from IPython.display import Image

# dot_data = tree.export_graphviz(clf, feature_names=X.columns, class_names=['mammals','non-mammals'], filled=True, 
#                                 out_file=None) 
# graph = pydotplus.graph_from_dot_data(dot_data) 
# Image(graph.create_png())
# Out:
#                             precision    recall  f1-score   support
#
#  Environmental Maintenance       0.99      0.98      0.98       625
# Infrastructure Maintenance       0.80      1.00      0.89       267
#                Inspections       1.00      1.00      1.00      1617
#               Public Works       1.00      0.63      0.77       171
#
#                   accuracy                           0.97      2680
#                  macro avg       0.95      0.90      0.91      2680
#               weighted avg       0.98      0.97      0.97      2680
# 0.9720149253731343

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
print(classification_report(y_test, y_pred))
rf_model.score(X_test, y_test)
# Out:
#                             precision    recall  f1-score   support
#
#  Environmental Maintenance       1.00      0.99      0.99       625
# Infrastructure Maintenance       0.98      0.99      0.99       267
#                Inspections       1.00      1.00      1.00      1617
#               Public Works       0.98      0.98      0.98       171
#
#                   accuracy                           0.99      2680
#                  macro avg       0.99      0.99      0.99      2680
#               weighted avg       0.99      0.99      0.99      2680
# 0.9940298507462687

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Split dataset into test and train
array = raw_data['category']
X_train, X_test, Y_train, Y_test = train_test_split(dummies, array, test_size=0.3, random_state=1)

# names going to be tested
models = []
#models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))

# evaluate each model
results = []
names = []

# Use 10-fold cross validation to estimate the accuracy of each model
for algorithm, model in models:
    k_fold = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
    cv_estimates = cross_val_score(model, X_train, Y_train, cv=k_fold, scoring='accuracy', )
    results.append(cv_estimates)
    names.append(algorithm)
    print('%s: %f ' % (algorithm, cv_estimates.mean()))


# Compare names
plt.boxplot(results, labels=names)
plt.title('Algorithm Comparison')
plt.show()

for algorithm, model in models:
    #Make predictions on test dataset
    model.fit(X_train, Y_train)
    model_predictions = model.predict(X_test)
         
    # Evaluate predictions
  
    print("\nAccuracy Score: ", accuracy_score(Y_test, model_predictions))
    print("\nClassification Report: \n", classification_report(Y_test, model_predictions))
# Out:
# CART: 0.999520
# NB: 0.984325
# Accuracy Score:  0.9996268656716418
#
# Classification Report:
#                              precision    recall  f1-score   support
#
#  Environmental Maintenance       1.00      1.00      1.00       606
# Infrastructure Maintenance       1.00      1.00      1.00       280
#                Inspections       1.00      1.00      1.00      1598
#               Public Works       1.00      0.99      1.00       196
#
#                   accuracy                           1.00      2680
#                  macro avg       1.00      1.00      1.00      2680
#               weighted avg       1.00      1.00      1.00      2680
#
#
# Accuracy Score:  0.9813432835820896
#
# Classification Report:
#                              precision    recall  f1-score   support
#
#  Environmental Maintenance       0.96      0.98      0.97       606
# Infrastructure Maintenance       0.99      0.96      0.98       280
#                Inspections       0.99      0.98      0.99      1598
#               Public Works       0.94      0.99      0.96       196
#
#                   accuracy                           0.98      2680
#                  macro avg       0.97      0.98      0.97      2680
#               weighted avg       0.98      0.98      0.98      2680

# %%
points = new_service_requests['location_1']
print(points)
# Out:
# 0        POINT (-89.980009613 35.147453143)
# 1        POINT (-89.839880001 35.096020007)
# 2           POINT (-89.941332 35.089373996)
# 3        POINT (-89.925832017 35.174220984)
# 4        POINT (-90.100066974 35.021354014)
#                         ...
# 12107     POINT (-90.00515399 35.146746992)
# 12108    POINT (-90.046767038 35.116150992)
# 12109     POINT (-89.91005803 35.093314999)
# 12110    POINT (-89.947418016 35.118521017)
# 12111    POINT (-89.997416991 35.240968007)
# Name: location_1, Length: 12112, dtype: object

# %%
areas = service_requests['area']
areas.unique()
# Out:
# array([nan, 'D', 'C', 'A', 'E', 'B', 'F'], dtype=object)

# %%
addresses = service_requests['address1']
unique_addresses = addresses.unique()
unique_addresses.size
# Out:
# 10704

# %%
summaries = service_requests['resolution_summary']

for s in summaries:
  if not isinstance(s, float):
     print(f'{s} \n')
# Out:
# Property in Violation
#
# PROPERTY TOTALLY REMODELED
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED FOR INOPERABLE VEHICLES,  OPEN STORAGE UNDER CARPORT AND TRAILER ON GRASS IN THE REAR OF PROPERTY WITH OPEN STORAGE ON IT. Notice Printed and mailed 12/07/23 not attached in oracle A Coleman ( unable to enter notes in job notes )
#
# The OWNER WAS FIXING UP THE HOUSE AND RESOLVING THE ISSUE WITH THE HOUSE
#
# Printed and mailed notice 02/15/2024 A Coleman
#
# 11-17-22 WORK PROGRESS AT TIME OF RECHECK.
#
# ISSUED VIOLATION TO THE OWNER: PHILADELPHIA CHURCH OF GOD IN CHRISTOwner Address:CHARLES J COWANS  1625 WOOD MILLS DR E  CORDOVA TN 38016-1626
#
# AT THE TIME OF INSPECTION, A NOTICE OF INTENTION TO IMPOUND  VIOLATIONS WERE ISSUED.
#
# ISSUED VIOLATION TO THE OWNER:ï¿½TUCKER EARL
# Owner Address:
# ï¿½PO BOX 1954ï¿½
# CHICAGOï¿½ILï¿½60690
#
# Property in Violation
#
# refer to commercial, closed
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR INOPERABLE VEHICLES PARKED ON THE GRASS.
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# PRINTED AND MAILED 02/16/2024
#
# SONYA MOMIN - 571-830-9630 - HEARING RE-SET FOR 02/21/2020
#
# AT THE TIME OF RE-INSPECTION THE GRASS WAS CUT
#
# FILE REVISED TO GIVE NEW OWNER PROPER NOTICE.
#
# 10.4.23 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED FOR YARD. TS FOLLOW UP 10.18.23
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½FBM LLCOwner Address:ï¿½2106 NE 15TH ST ï¿½FORT LAUDERDALEï¿½FLï¿½33304-1439
#
# 01-30-2024 BACK TO MCSC, REFER TO SHELBY COUNTY CODE ENFORCEMENT (JN)
#
# Property in Violation
#
# 03-16-2024 BACK TO MCSC, REFER TO HEALTH DEPT(JN)
#
# Property in Violation
#
# MS. NIKI BREWER- 901-361-7674
#
# Property is being written up for  Rehab
#
# Property in Violation
#
# NEW OWNER- GIVEN BACK ON 03/26/2021
#
# 08/18/23 A VIOLATION WAS ISSUED FOR BOARD AND SECURE PROPERTY FOLLOW UP DATE 09/18/23
#
# 3/2/24 MCSC REFER TO COUNTY CODE
#
# Repair front of the building.
#
# Property in Violation
#
# 01-23-2024 BACK TO MCSC, REFER TO EE COMPLAINTS(JN)
#
# follow up date 9-15-2022
#
# Active NPA Case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR NON-COMPLIANCE WITH A COURT SUMMONS DATE OF 3/21/2024.
#
# 9.5.2023, ISSUED NOTICE TO REMOVE OPEN STORAGE ITEMS FROM PROPERTY
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# MR. ADRIAN TURNER- 901-513-4731
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# 10.17.23 AT THE TIME OF RECHECK TREE HAS BEEN REMOVED. OWNER WORKING ON ROOF TS 11.17.23
#
# 1.25.23 NOTES BACK TO MCSC FOR MPD
#
# NOTES 1.23 24 AT THE TIME OF INSPECTION BACK TO MCSC FOR MPD VEHICLES ON STREET
#
# Property in Violation
#
# 10-18-23 AT THE TIME OF FOLLOW UP INSPECTION THERE WAS NO PROGRESS MADE FINAL NOTICE ISSUED F/U 11-1-23
#
# MR. TERRY HOWELL- 901-438-3615.
#
# 1-11-24 VACANT LOT IS A SHELBY COUNTY PROPERTY
#
# 10-16-2023 Refer back to commercial
#
# Property in Violation
#
# Property in Violation
#
# NOTICE TO CORRECT WAS ISSUED
#
# Owner filed CD-Appeal
#
# Property in Violation
#
# Property in Violation
#
# Inspection revealed junk, debris & garbage scattered throughout premises. Dilapidated fence. Backed up sewer line w/ evidence of grease. Issued violation to abate & filed complaint with SC Health Dept. for illegally dumping grease in drain 12.1.21 TF
#
# ISSUED VIOLATION CERT MAIL TO THE OWNER:ï¿½SRW INCOwner Address:ï¿½236 BREMINGTON PL ï¿½MEMPHISï¿½TNï¿½38111-6007
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# AT THE TIME OF INSPECTION SIGNIFICANT PROGRESS HAS BEEN MADE ON REPAIR. FOLLOWING UP ON 1/15/2024 FOR COMPLIANCE.
#
# PRINTED AND MAILED 3/16/2024 Z.W.
#
# Property in Violation
#
# Property in Violation
#
# SHELBY COUNTY PROPERTY
#
# Property in Violation
#
# The structure has been burned by fire and written up to be rehabbed.
#
# Property in Violation
#
# NOTICE ISSUED TO REPAIR POTHOLES IN PARKING LOT
#
# Back To MCSC forward to MPD
#
# VACANT HOME IN NEED OF REPAIR
#
# Property in Violation
#
# Property in Violation
#
# KYLE BENNIE ph: 901-833-4507- OWNER CALLED AND STATED THAT HE WILL BE STARTING THE REPAIRING WORK SOON- MA
#
# Property in Violation
#
# PRINTED AND MAILED 02/16/2024
#
# Reference Inc ID 7015408. This incident ID was received at the same time as 7015408 due to 311 link not working with StormWater Dept. Inspection was conducted same day and noted under 7015408
#
# SEND TO STREET MAINTENANCE
#
# ï¿½ï¿½ï¿½
#
# Condemnation hearing scheduled for January 25, 2024 @ 9:30 am
#
# Pickup
#
# Call Nikki Westmorland regarding property - 901-507-3423
#
# HEARING RE-SCHEDULED FOR  07/02/2018-MA
#
# 1-25-23 ISSUED A FINAL NOTICE
#
# Property in Violation
#
# Property in Violation
#
# PLEASE ATTACH VOYC 9/19/2023-MC
#
# EXTENSION GIVEN BY A. MUHAMMAD TILL 09/27/2021 TO START THE REPAIRING WORK- PH: 917-545-6976- MR. DRAGON KOCIC- FORMER CO- OWNER
#
# AT TIME OF INSPECTION STRUCTURE WAS IN COMPLIANCE. HIGH WEEDS AND GRASS AND JUNKY YARD
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# NEEDS TO GO BACK TO MCSC
#
# Property in Violation
#
# AT THE TIME OF INSPECTION THIS NEEDS TO GO BACK TO MCSC FOR POLICE SERVICES DUE TO INOPERATIVE VEHICLE PARKED ON THE STREET.
#
# Property in Violation
#
# 12.13.2022,PROPERTY BOARDED UP
#
# MAILED FM-5L, FM-15 AND JW-DM 02/14/2024
#
# NO PROGRESS. IN TAX SALE
#
# 3/11/24 AT THE TIME OF INSPECTION TRANSFER SR TO MPD VEHCILE PARKED ON THE STREET.
#
# AWATING investigation request form for property owners information
#
# Owner granted 90 days repair
#
# Property in Violation
#
# DR. JODI RUMP- 901-277-7551.
#
# SHELBY COUNTY OWNS PROPERTY
#
# AT THE TIME OF INSPECTION THE VIOLATION NEEDS TO GO BACK TO MCSC FOR INOPERABLE VEHICLE PARKED ON STREET.
#
# WROTE UP PROPERTY TO BE REHABBED
#
# 10.4.23 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED FOR DAMAGED POOL IN YARD TS FU 11.4.2023
#
# Property in Violation
#
# WROTE UP PROPERTY TO BE REHABBED
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHABILITATION.
#
# Send to SHELBY COUNTY this is a Rehab Center
#
# PRINTED AND MAILED FINAL NOTICE 02/21/2024
#
# Property in Violation
#
# POTHOLES ON PROPERTY UNSAFE ISSUED VIOLATION TO THE OWNER
#
# Property in Violation
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# EDWARD L NIVENS - 901-382-9374
#
# MR. RODNEY JOHNSON-901-215-7317.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# SENT TO COUNTY CODE
#
# Property in Violation
#
# Property in Violation
#
# back to mcsc , foward to commerical code
#
# Property in Violation
#
# No Potholes found - Contact 311 with more information
#
# Property in Violation
#
# MAILED FM-5L, FM-5, FM-15 AND JW-RH 03/16/2025
#
# COM Ordinance mailer sent
#
# Property in Violation
#
# AT THE TIME OF INSPECTION PROPERTY WAS IN COMPLIANCE.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# OWNER WILL BE COMING ON 05/06/2019 INSTEAD OF 04/08/2019, PH:901-949-4726- MR. MILLER
#
# 10.30.23 PROPERTY IS IN COMPLIANCE
#
# PRINTED AND MAILED 2/21/2024 Z.WILLIAMS
#
# AT THE TIME OF INSPECTION VIOLATION WAS CORRECTED.
#
# WROTE PROPERTY UP TO BE REHABBED
#
# Remove Graffiti
#
# � VEHICLE IS PARKED ON THE STREET.� NEEDS TO GO BACK TO MCSC.
#
# Property in Violation
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# Property in Violation
#
# Property in Violation
#
# 01/02/24 At time of reinspection all is ok.
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHAB.
#
# TRANSFER SR TO MPD VEHCILE PARKED ON THE STREET.
#
# SEE SR#50016253
#
# THIS PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# PROPERTY INSPECTED AND INVESTIGATION REQUEST SUBMITTED FOR OWNER INFORMATION.
#
# MR. RON FLOYD- 901-859-2105
#
# ESSIE GRAY- 901-380-1502
#
# Property in Violation
#
# THIS PROPERTY WILL BE WRITTEN UP FOR REHAB
#
# ID2 MAILED 07/28/2023 ID2 POSTED 7/31/2023
#
# CALEM FOGLEMAN- NO PHONE NUMBER- BORROWED FROM FRIEND TO CONTACT US.
#
# PRINTED AND MAILED 02/20/2024
#
# ISSUED VIOLATION TO THE OWNER
#
# CORI CLARK- 323-294-0094
#
# PRINTED AND  MAILED 02/20/2024
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# PRINTED AND MAILED 3/16/2024 Z.W.
#
# Property in Violation
#
# MS. LACHELLE LONG- 615-483-0375.
#
# NPF11-1 DISGARD CODE -NEW OWNERSHIP
#
# PROPERTY IS BEING WRITTEN UP FOR CONDEMNATION
#
# RESIDENTIAL
#
# LAQUINTA PARTEE- 901-431-1507- DECEASED OWNER'S GRAND DAUGHTER
#
# MR. TERRENCE GOLSTON- PH: 901-921-2814
#
# Property in Violation
#
# WILLIE YANCEY-PH: 901-598-2149
#
# FOLLOW-UP 12/02/2022
#
# Property in Violation
#
# NOTICE ISSUED TO REMOVE INOPERABLE TOW TRUCK ON VACANT LOT.
#
# FW TO REPAIR
#
# Property in Violation
#
# MR. DREW 901-260-3125- MANAGEMENT COMPANY REPRESENTATIVE
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# Property in Violation
#
# T164697
#
# ISSUED VIOLATION TO THE OWNER
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHABILITATION.
#
# MR. KENNETH DUPREE- 615-429-0870
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# Property in Violation
#
# MR. JOSEPH- 901-361-6363- WILL BE NEW OWNER- ALREADY STARTED THE WORK
#
# Property in Violation
#
# property secured by the city
#
# 02-09-2023 AT THE TIME OF THE INSPECTION THERE WERE MOLD LIKE SUBSTANCE THROUGHOUT THE ENTIRE HOUSE AND RUNNING WATER COMING FROM THE TOILET FACILITIES, ALSO BROKEN WINDOWS IN THE FRONT OF THE HOUSE
#
# NOTES: 1-5-24, REFERRED TO MPD.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# ISSUED VIOLATION ON INTERIOR FOLLOW UP 6-24-22
#
# ?BACK TO MCSC
#
# Property in Violation
#
# INOPERABLE VEHICLE ON THE STREET WAS REFERRED BACK TO MCSC MPD
#
# AT THE TIME OF INSPECTION VEHICLE PARKED ON THE STREET NEEDS TO GO BACK TO MCSC
#
# Property in Violation
#
# see sr 5264626 active Commercial SR
#
# MR. MAURICE BATTS-PH: 678-614-8405
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# HCD PROPERTY....
#
# NPA COURT DATE SET FOR 10/19/2023 @ 1:30PM
#
# deliver 1 cart
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# Property in Violation
#
# FILE GIVEN BACK TO MR. HOKES AS MR. SHELTON R. PARKS IS NOT THE OWNER OF THIS PROPERTY
#
# WROTE UP PROPERTY TO BE REHABBED
#
# CVOYC
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# New owner granted 90 Days Repair
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# NOTICE TO CORRECT WAS ISSUED
#
# ISSUED VIOLATION TO OWNER: LUCCHESI, IRMA DOwner Address: 5951 BRIERHEDGE AVE  MEMPHIS TN 38120
#
# ISSUED VIOLATION TO THE Owner:ï¿½PALAZOLA, MICHAEL A AND ALICE FACELLI AND JENNIFER SMITH AND ANGELINE KOLWYCK Owner Address:
# PRETTI BROS GRO ï¿½5002 S 3RD ST ï¿½
# MEMPHISï¿½TNï¿½38109-6232
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Demolish property
#
# holes in ceiling, leakage coming through ceiling
#
# back to mcsc
#
# New owner filed CD-Appeal 01/05/2024
#
# deliver 1 cart
#
# follow-up 5/3/2023
#
# OCCUPANTS COMPLAINED OF NO HEAT IN THE PROPERTY. AFTER SPEAKING WITH THE PROPERTY MANAGER 'DIRT' HE INFORNED ME THAT THIS IS HIS COUSINS PROPERTY AND GAVE ME THE WRONG PHONE NUMBER. AFTER FURTHER INSPECTION PROPERTY IS IN NEED OF REHAB .
#
# Property in Violation
#
# (MR. MIKE- 216-308-5934 SAFEGUARD PROPERTIES-AGENT FOR FANNIE MAE COMPANY)PH: 487-1919
#
# Property in Violation
#
# PRINTED AND MAILED 02/20/2024
#
# Property in Violation
#
# MS. TRACY GREEN- 901-268-7300.
#
# Property in Violation
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# CREATED WRITE UP SUBMITTED
#
# Property in Violation
#
# WILLIAM WINBUSH- PH:832-648-8453
#
# Property in Violation
#
# Rehab the structure and remove excess debris.
#
# Property in Violation
#
# Property in Violation
#
# NOTICE ISSUED TO CUT EXCESSIVE GRASS FROM PROPERTY
#
# Rehab property
#
# 11-16-23 WORK PROGRESS
#
# HEARING RE-SET FOR 01/10/2020- MR. KEITH REEDUS- 901-606-7656
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# Property in Violation
#
# DOLA RIVERS- 901-288-6841- WORKS FOR THE OWNER
#
# PRINTED AND MAILED 10/19/2023-BHUMPHREY
#
# Property in Violation
#
# Property in Violation
#
# 10.16.23 AT THE TIME OF RECHECK A FINAL NOTICE ISSUED FOR INOPERABLE VEHICLES TS FOLLOW UP 10.29.23
#
# Recommend demolition of the structure
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER: MOORE, JOHN HOwner Address: 1450 S PARKS RD  LAKE CORMORANT MS 38641
#
# 03-02-2024 BACK TO MCSC, NOT A RESIDENTIAL CODE VIOLATION,  REFER TO COMMERCIAL(JN)
#
# Property in Violation
#
# Serviced by Public Works
#
# RESIDENTIAL
#
# MIKE SNAB- 901-864-0412
#
# GATED PROPERTY
#
# MS. BERTHA MCDANIEL-901-644-7509.-OWNER'S DAUGHTER
#
# Property in Violation
#
# Property in Violation
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# residential property
#
# Owner granted 90 days repair
#
# 2-13-24 VEHICLE REMOVED FROM GRASS AT THE TIME OF INSPECTION
#
# 02/27/23 AT TIME OF  INSPECTION  PROPERTY WAS IN COMPLIANCE
#
# PROPERTY WAS WRITTEN UP FOR REHAB
#
# Property in Violation
#
# Property in Violation
#
# PRINTED AND MAILED 2/14/2024 Z.WILLIAMS
#
# Property in Violation
#
# SEND TO POLICE
#
# Property in Violation
#
# Property in Violation
#
# 3-18-24 THERE WAS NO VIOLATION PRESENT AT THE TIME OF INSPECTION
#
# Property in Violation
#
# AT THE TIME OF INSPECTION REPOSTED NOTICE VIOLATION.
#
# Contact KENNY SHAW 901-205-4338 FOR INSPECTION
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP REHAB.
#
# WILLIAM GREEN- 901-230-6957- HEARING RE-SET FOR 01/09/2020
#
# Property in Violation
#
# WRONG ADDRESS
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½BATES ANNETTE AND CARMELIA BATES AND TONY BATES AND JIMMY BATES ANDOwner Address:ï¿½4586 BERTA RD ï¿½MEMPHISï¿½TNï¿½38109-5906
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# 01-23-2024 BACK TO MCSC, REFER TO SANITATION(JN)
#
# deliver 1 cart
#
# Property in Violation
#
# PRINTED AND MAILED 2/13/2024 Z.WILLIAMS
#
# NOTICE TO CORRECT WAS ISSUED
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# 3-6-24 INOPERABLE VEHICLE PARKED ON STREET
#
# ISSUED VIOLATION TO THE NEW OWNER: WORLDWIDE PRESTIGE GROUP LLCIn Care Of Owner Address:PO BOX 2185Owner City/State/Zip:MEMPHISï¿½TNï¿½38101-ï¿½2185
#
# ISSUED VIOLATION TO THE OWNER
#
# Hearing held 03/07/2023
#
# WROTE UP PROPERTY TO BE REHABBED
#
# PRINTED AND  MAILED 02/20/2024
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# Property in Violation
#
# Property in Violation
#
# Cart not located
#
# NOT A DERELICT STRUCTURE
#
# NOTICE TO CORRECT ISSUED FOR JUNKY YARD
#
# back to mcsc forward to commercial code
#
# Property in Violation
#
# Property in Violation
#
# TS-ORDERED 11/17/2023
# TS-RECEIVED, 11/11/21/2023
# SC LETTER MAILED 11/27/2023
#
# Property in Violation
#
# ï¿½ï¿½ï¿½ï¿½
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# JUSTIFIED ACTIVE TO SERVICE REQUEST 6217196
#
# Property in Violation
#
# send to Shelby County code
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½CARODINE MARTINOwner Address:ï¿½2750COLLIERVILLE ARLINGTONï¿½EADSï¿½TNï¿½38028
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# HEARING RE-SET FOR 11/20/2019- MR. WILLIAM FORRESTER- 901-513-7062
#
# Cut high grass and weeds, make appt. to inspect the interior of the building.
#
# SABRINA CAMPBELL- 901-461-9004
#
# WROTE UP PROPERTY TO BE REHABBED
#
# MR. MONIQUE BELL- 901-230-0417, AND 901-679-8416.
#
# NOTICE TO CORRECT WAS ISSUED FOLLOW UP DATE 05-09-2023
#
# AT THE TIME OF INSPECTION REAR FENCE IS DAMAGED AND UPROOTED AND NEEDS REPAIR.
#
# ï¿½ï¿½ï¿½
#
# wrote up property to be rehabbed
#
# Property in Violation
#
# YAMEL CONSTANTINO- 720-717-1794
#
# Roof needs to be rehabbed.
#
# Property in Violation
#
# CVOID - SR#50010636
#
# PRINTED AND MAILED 02/16/2024
#
# Property in Violation
#
# Property in Violation
#
# SUBMITTED CREATED WRITE UP
#
# 12-21-22 AT THE TIME OF INSPECTION NO VIOLATION WAS OBSERVED
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED NON-COMPLIANCE ON REPAIRING DAMAGED FENCE.
#
# JWDM CREATED FOR A SEVERLY DAMAGED AND VACANT PROPERTY , SEPT.30,2022
#
# Property in Violation
#
# Printed and mailed notice 02/16/2024 A. Coleman
#
# PRINTED AND MAILED 02/20/2024
#
# ISSUED VIOLATION TO THE OWNER: SAM'S REAL ESTATE BUSINESS TRUSTOwner Address: PO BOX 8050 BENTONVILLE AR 72712-8055
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# REFER TO MPD FOR AN INOPERATIVE WRECKED BLACK CADILLAC ESCALADE IS PARKED ON THE STREET IN FRONT OF PROPERTY 2915 CLEARWOOD RD.
#
# T162869
#
# Property in Violation
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# Property in Violation
#
# WROTE UP PROPERTY TO BE IN CONDEMNATION
#
# BENJAMIN HARVELL-615-500-3535 ,  615-546-8267
#
# OWNER'S SON- 440-723-7388
#
# ISSUED VIOLATION TO THE OWNER: PAYNE, PATRICIAOwner Address: 912 MCCLURE RD  MEMPHIS TN 38116-7716
#
# Property in Violation
#
# Property in Violation
#
# 2/8 --- 18wheeler not there time of Inspection.  Will Monitor to Ensure compliance
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# Property in Violation
#
# Active NPA Case
#
# please rehab or demolish property
#
# THS IS A RESIDENTIAL CODE ISSUE
#
# Property in Violation
#
# WPP PER INSPECTOR D. BURTON 06/17/20 WPP PER INSPECTOR R.LAKE
#
# No Potholes found - Contact 311 with more information
#
# MR. WILLIAM STREET-901-301-6482
#
# N OTICE TO CORRECT ISSUED FOLLOW UP DATE 05-24-2023
#
# WPP PER INSPECTOR R.WITTER
#
# Property in Violation
#
# Property in Violation
#
# Owner filed appeal
#
# WRITTEN UP FOR REHAB
#
# PROPERTY HAS BEEN WRITTEN UP FOR CONDEMNATION
#
# Property in Violation
#
# Property in Violation
#
# 10-26-2023 BACK TO MCSC,  REFER TO GROUNDS DEPT.  PROPERTY IS VACANT (JN)
#
# ISSUED VIOLATION FOLLOW UP DATE 7-11-22
#
# Property in Violation
#
# Please contact MAC at 222-2300 and refer to  ticket number W385888.
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# FOLLOW-UP 9/10/2023
#
# 11.3.23 AT THE TIME OF RECHECK ONLY A FEW CHANGES WERE MADE FU 11/17/23
#
# moody andrea- 901-785-3869-HEARING RE-SET FOR 01/13/2020
#
# Property in Violation
#
# NOTICE TO CORRECT ISSUED
#
# WROTE UP PROPERTY TO BE REHABBED
#
# MS. LISA -901-646-6000- REPRESENTATIVE FOR O'S REALTY.
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR WATER DAMAGE ON WALL AND FLOOR/CARPET, BATHROOM TILE DAMAGE & MOLD-LIKE SUBSTANCES AND STOVE NOT COMPLETELY OPERATIONAL.
#
# PROPERTY WAS REFERRED BACK TO MCSC GROUNDS
#
# MS. CANDICE 901-350-0500
#
# Property in Violation
#
# BACK TO MCSC FORWARD TO MPD/ OWNER LIVING IN THE CAR AT THE TIME OF THE INSPECTION
#
# 10-18-23 ISSUED FINAL NOTICE F/U 11-1-23
#
# Property in Violation
#
# REFER TO SR# 5923854
#
# NOTICE TO CORRECT WAS ISSUED FOLLOW UP DATE 05-24-2024
#
# TAMEKA DANIELS- 901-326-5527-  08/07/20 WROTE UP PROPERTY FOR REHAB
#
# Property in Violation
#
# MARCOS D- OWNER - PH:305-725-0183  ,  JUAN MANCEL-CONTRACTOR 786-263-2551
#
# PRINTED AND MAILED 03/15/2024
#
# WPP PER INSPECTOR J. NORMAN
#
# PRINTED AND MAILED 2/14/2024 Z.WILLIAMS
#
# WROTE UP PROPERTY TO BE REHABBED
#
# NOTICE TO CORRECT ISSUED  FOLLOW UP DATE 05-24-2023
#
# Full inspection completed with the owner. Rehab in progress 11.22.21 TFry; Continued work progress 2.8.22
#
# MELVIN MALLORY- 901-554-0867
#
# Property in Violation
#
# 01/25/24 At time of reinspection all is ok. Electrical box is repaired.
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY IS BEING WRITTEN UP FOR CONDEMNATION
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# PENDING SHELBY COUNTY TAX SALE 19.04 06/27/2023
#
# PROEPRTY HAS BEEN INSPECTED ADN WRITTEN UP FOR REHAB
#
# REFERRED TO MPD.
#
# SQT 129- CODE ZERO PRINTED AND MAILED 3/16/24
#
# Owner granted 90 Days Repair
#
# .MR. WHMON BROWN-HOME 901-396-4816 AND CELL 901-493-1835.
#
# CONDITIONS HAVE CHANGED REVISED TO CD
#
# 12.1.23 AT THE TIME OF INSPECTION VIOLATION SENT BACJ TO MCSC FOR MPD. VEHICLE ON STREET
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# At the time of inspection the residence was severely damaged. A notice was issued.
#
# 10.5.23 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED FOR INOPERABLE GATE TS FU 11/5/23NOTES 12.19.23 FINAL NOTICE ISSUED FOR INOPERABLE GATE FU 2.2.24
#
# Property in Violation
#
# CR STRUCTURAL MAINTAINANCE ONGOING
#
# High Weeds Vacant Lot
#
# property is being written up for rehab
#
# commercial property
#
# DEBRIS IN THE FRONT YARD OF THIS VACANT PROPERTY NEEDS TO GO BACK TO MCSC.
#
# back to mcsc, residential, close
#
# NOTICE ISSUED TO REPAIR POTHOLES IN PARKING LOT
#
# PRINTED AND MAILED 2/13/2024 Z.WILLIAMS
#
# 10.17.23 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED TO BOARD/ SECURE AS WELL AS CLEAN OPEN STORAGE F/U 10.31.2023
#
# Property in Violation
#
# Property in Violation
#
# COREY DAVIS- 901-334-7278
#
# ISSUED VIOLATION TO THE OWNER: DIXIE WAX PAPER COOwner Address:BRYCE DIXICO INC ï¿½PO BOX 18338ï¿½MEMPHISï¿½TNï¿½38181
#
# Property in Violation
#
# deliver 1 cart
#
# Redemption period has completed. Condemnation hearing notice mailed certified on 06/12/2023 and notice given to inspector to post on the property. JT
#
# Board and Secure.
#
# MS. JACQUELINE A JONES- 901-691-1752
#
# owner filed CD-Appeal
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# CREATED WRITEUP
#
# state route refer to TDOT
#
# owner to trim tree branches, meeting with owner to inspect area
#
# ISSUED VIOLATION TO THE OWNER: HENDERSON WILLIE JROwner Address: 7560 FAIRWAY FOREST DR N  CORDOVA TN 38016-5730
#
# 3-6-24 INOPERABLE VEHICLE PARKED ON STREET
#
# Grass and hedges cut, light debris in grass
#
# ISSUED VIOLATION TO THE OWNER: Owner:ï¿½CARR SHELDON A
# Owner Address:
# ï¿½1199 FIBER RD ï¿½
# MEMPHISï¿½TNï¿½38109-3410
#
# back to mcsc forward to commercial code. properties are both secured
#
# Owner was given an extended 30-60 days to monitor.
#
# Property in Violation
#
# Property in Violation
#
# PROPERY WAS WRITTEN UP FOR REHABBED
#
# TALKED TO THE TEANANT AND SHE SAID GIVE HER A LITTLE MORE TIME IT WILL BE GONE
#
# Property in Violation
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# Active NPA Case
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# MS. HAZEL JONES- 901-237-4125
#
# Property in Violation
#
# Property in Violation
#
# MALCOL HOLLIDAY - 901-210-8143- NEW OWNER- HE BOUGHT THE PROPERTY IN TAX SALE IN FEB 2021- WAITING FOR THE REDEMPTION PERIOD-HE WILL BE RENOVATING  MA
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# ISSUED A VIOLATION TO REMOVE GRAFFITI
#
# WROTE UP PROPERTY TO BE REHABBED
#
# 11-16-23 UPDATED PICTURES
#
# Property in Violation
#
# Property in Violation
#
# MR. KEVIN GIBSON- 901-519-5601
#
# Property in Violation
#
# Issued Final notice
#
# Property in Violation
#
# Property in Violation
#
# VACANT PROPERTY WAS REFERRED BACK TO MCSC GROUNDS
#
# FW TO REPAIR
#
# Property in Violation
#
# Property in Violation
#
# HEARING RE-SCHEDULED FOR 12/12/2018, THEN FOR 12/17/2018
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR FLOOR  TO BE REPAIRED.
#
# Shelby County Owned Property. Please contact the Shelby County Land Bank at 901-222-2575 for further information.
#
# Property in Violation
#
# VEHICLE ON THE STREET WAS REFERRED BACK TO MCSC- MPD
#
# Property in Violation
#
# THIS PROPERTY IS BEEN WRITEN UP FOR REHAB. POSTED RETURN MAIL
#
# Property in Violation
#
# MAIL COPIES TO -DeBerry SPND(s) 7575 COCKRILL BEND BLVD, NASHVILLE, TN 37209
#
# GIVEN BACK TO SUPERVISOR ON 11/15/2019, WRONG HOUSE PICTURES AND INSPECTION REPORT
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# MLGW - This falls under the purview of MLGW. Any further inquiries should be directed to them.
#
# ï¿½ï¿½ï¿½
#
# THE PROPERTY OWNER AUGUSTUS JACKSON CALLED FROM 901-355-6146 @ 5256 ALGIERS DR AND SAID HE RECVD THE VIOLATION HE RECENTLY HAD A BABY THE PROPERTY IS BEING CLEANED AND DEBRIS BEING REMOVED / I ADVISED I WILL DO A FOLLOWUP INSPECTION FOR PICS
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR OPEN STORAGE UNDER CARPORT.
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED NON-COMPLIANCE ON REPAIRING DAMAGED FENCE.
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED HIGH GRASS AND WEEDS AND OPEN STORAGE ON THE PROPERTY.
#
# AT THE TIME OF INSPECTION SENT BACK TO MCSC FOR  POLICES SERVICES DUE TO INOPERABLE VEHICLE PARKED ON STREET.
#
# PRINTED AND  MAILED 02/20/2024
#
# Property in Violation
#
# Property in Violation
#
# PRINTED AND MAILED 2/16/2024 Z.WILLIAMS
#
# active NPA case
#
# Property in Violation
#
# 03-02-2024 BACK TO MCSC, NOT A RESIDENTIAL CODE VIOLATION,  REFER TO COMMERCIAL(JN)
#
# 03/29/23 At time of reinspection all is ok.
#
# Property in Violation
#
# JOSEPH D- 901 382-2007 OR 901-282-2007- OWNER CAME TO THE OFFICE AND LEFT HIS PHONE NUMBERS
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# NPP PER INSPECTOR Q. GILCHREST- MA
#
# PRINTED AND MAILED 02/20/2024
#
# Property in Violation
#
# 01-03-2024 BACK TO MCSC, REFER TO SHELBY COUNTY(JN)
#
# BACK TO MCSC SHELBY COUNTY
#
# 01/18/24 AT THE TIME OF INSPECTION PROPERTY WAS IN COMPLIANCE
#
# Remove Graffiti
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# WHITE INOPERABLE VEHICLE ON THE STREET WAS REFERRED BACK TO MCSC MPD
#
# 10.3.23 SERVED VIOLATION TO CB PROPERTY F/U 11.2.23
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# 11-07-2023 BACK TO MCSC,  REFER TO GROUNDS DEPT (JN)
#
# Property in Violation
#
# Property in Violation
#
# MUHAMMAD SHAREEF- 909-645-7525-HEARING RE-SET FOR 11/25/2019
#
# Property in Violation
#
# PRINTED AND MAILED 03/15/2024
#
# Property in Violation
#
# NOTICE MAILED TO OWNER ADDITIONAL ADDRESS OF 2704 ALYSHEBA AVE  MODESTO , CA 95355-8435 PER USPS. 2/14/24 A. COLEMAN
#
# Property in Violation
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½WILLIAMS SHELLEY B & LUE E AND
# Owner Address:
# ï¿½3490 DAGGETT RD ï¿½
# MEMPHISï¿½TNï¿½38109
#
# Rescheduled hearing
#
# 2-22-22 REFER TO SR#5589388
#
# 9/16/22 CVOAR VEHICLE REMOVED AT TIME OF INSPECTION
#
# 12/14/2023 BACK TO MCSC, REFER TO ENVIRONMENTAL ENFORCEMENT(JN)
#
# Diane Crrout 901-388-3705
#
# Z 11 2886 replaced with new T166734
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# ï¿½ï¿½ï¿½
#
# TONY DEBERRY- 901-281-1773
#
# Property in Violation
#
# Notify inspector on the progress of rehab.
#
# Property in Violation
#
# MR. ERIC MORROW- 312-493-9020
#
# PROPERTY WAS WRITTEN UP FOR REHAB
#
# Property in Violation
#
# Property in Violation
#
# PRINTED AND MAILED 2/16/2024 Z.WILLIAMS
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A FINAL NOTICE WAS ISSUED FOR DAMAGED FENCE.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# THIS IS A RESIDENTIAL ISSUE
#
# MR. CURTIS WEBB- 901-573-0003
#
# TRAILER WAS REFERRED TO MCSC MPD
#
# AT THE TIME OF INSPECTION SENT BACK TO MCSC FOR EE TO ADDRESS.
#
# Property in Violation
#
# Vacant
#
# Property in Violation
#
# THE PROPERTY HAS BEEN WROTE UP FOR REHAB
#
# I went across the street and spoke with the SCS Warehouse storage Manager, Mr. White (whitek2@scsk12.org) and he stated that it was indeed an SCS recycling site and was very surprised to see that the parcel did not belong to SCS
#
# back to mcsc, residential, close
#
# COURT SUMMONS ISSUED
#
# 10/27/23 MCSC SOLID WASTE TRASH ON CURB FOR PICKUP
#
# Property in Violation
#
# Property in Violation
#
# Not a commercial code violation.
#
# Property in Violation
#
# id2 mailed and posted 02/10/2023
#
# Property in Violation
#
# MS. TAYLOR- 901-864-4951
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# AT THE TIME OF INSPECTION SIGNIFICANT PROGRESS HAS BEEN MADE. NEW AND FINAL F/U DATE IS 11/20/2023.
#
# Property in Violation
#
# Property in Violation
#
# Serviced by Public Works
#
# PROPERTY HAS BEEN WRITTEN UP FOR REHAB
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# QROTE UP PROPERTY TO BE REHABBED
#
# Please contact MAC at 901-222-2300.
#
# INOPERABLE TRAILER REFERRED BACK TO MCSC MPD
#
# Property in Violation
#
# 12.14 23 VIOLATION  WAS SENT BACK TO MCSC MPD
#
# 10.25.23 AT THE TIME OF RECHECK NO PROGRESS SHOWN FINAL NOTICE ISSUED FOR YARD TS FOLLOW UP 11.9.23
#
# Will re-access in a few weeks
#
# ISSUED VIOLATION TO THE OWNER
#
# ISSUED A INSPECTION REPORT TO OWNER OF RECORD TO REHAB BUILDING
#
# NEW ADDR FOR OWNER / VIOLATION REISSUED
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# Property in Violation
#
# WITH MR. JONE'S APPROVAL
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½OSBORNE, CARLON Owner Address: ï¿½1508 S WILLETTï¿½ MEMPHISï¿½TNï¿½38106
#
# AT  THE TIME OF INSPECTION THERE WAS NO VIOLATION PRESENT .
#
# Property in Violation
#
# Property in Violation
#
# NOTES 1.10.24 AT THE TIME OF INSPECTION VIOLATION ISSUED FOR YARD FU 1.24.24��
#
# ISSUED VIOLATION TO THE OWNER:ï¿½GIBSON LESLIE BOwner Address:ï¿½1526 RAYBURN ST ï¿½MEMPHISï¿½TNï¿½38106-8644
#
# SEND TO SANITATION
#
# Repair work needed underneath overhang in the front.
#
# court date 10-24-2022
#
# Property in Violation
#
# owner filed CD Appeal 01/12/2024
#
# Property in Violation
#
# Property in Violation
#
# THIS PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHABILITATION
#
# ï¿½ï¿½ï¿½
#
# ISSUED VIOLATION TO THE OWNER:ï¿½ALSHUGAA, MUSTAFAOwner Address:ï¿½315 W MITCHELL RD ï¿½MEMPHISï¿½TNï¿½38109
#
# illegal dumping
#
# LINDA ELLIS- 901-552-1745
#
# HEARING RE-SET FOR 11/10/2021- MR. RASHAWN BRYANT-979-645-3514-SON  AND MS. ELINDA BRYANT-901-572-3829-MOM
#
# THIS PROPERT IS BEING WRITTEN UP FOR REHAB
#
# Property in Violation
#
# High Weeds Vacant Lot
#
# Property in Violation
#
# Property in Violation
#
# only coughs at property is being rehabbed will have attended in by the end of the month
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER Owner:ï¿½GLENN JOHN ANDREW AND JEFFREY ALAN GLENNOwner Address:ï¿½2193ELVIS PRESLEYBLVD ï¿½MEMPHISï¿½TNï¿½38106-7735
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR INOPERABLE VEHICLES PARKED ON GRASS.
#
# Property in Violation
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# BACK TO MCSC / VEHICLES ARE PARKED ON STREET.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# LISA ROBINSON-901-827-4727- HEARING RE-SET FOR 02/12/2020
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# MR. ROBERT WOODS- 901-489-0383
#
# PRINTED AND MAILED 02/20/2024
#
# Property in Violation
#
# PROPERTY INSPECTED AND WRITTEN UP FOR REHAB.
#
# wrong address crunch fitness building
#
# Property in Violation
#
# FM-7-HEARING MISSED 03/04/2024
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# PICS ATTACHED
#
# 1.3.24 AT THE TIME OF INSPECTION NO VIOLATION ISSUED NOT JUSTIFIED BACK TO MCSC MPD
#
# Property in Violation
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER: PAYNE, DAVID EOwner Address:ï¿½5154 BERTA RD ï¿½MEMPHISï¿½TNï¿½38109-7355
#
# MR. ANDRE HOLMES- 901-650-3476
#
# Property in Violation
#
# MR. ERVIN PINSON- 321-586-7216
#
# Property in Violation
#
# constuction work going on unable to sweep
#
# BETTERVIEWRENOVATIONS@YAHOO.COM
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# commercial retail property
#
# 10.18.23 AT THE TIME OF RECHECK FINAL NOTICE ISSUED FOR YARD TO OWNER AND TENANT TS 11.01.23
#
# send to sanitation department
#
# Cut excessive grass.
#
# Property in Violation
#
# Property in Violation
#
# AT TIME OF INSPECTION PROPERTY WAS NOT INCOMPLIANCE PROPERTY HAD POT HOLES AND WAS NOT OPERATION MISSING GRATES AND MAN HOLE COVERS. SUBSTANDARD AND DERELICT STRUCTURE.
#
# WPP PER INSPECTOR J. NORMAN
#
# cut high grass and fill holes in the parking lot.
#
# MR. DRAGAN KOCIC- 901-345-9900- REPRESENTATIVE
#
# WORK PROGRESS
#
# Property in Violation
#
# PROPERTY WILL BE WRITTEN UP FOR REHAB
#
# Property in Violation
#
# VENDOR HAS BEEN ASSIGNED FOR BOARD UP. 5-7 DAYS FOR COMPLETION 1/30/2024. -DDH
#
# Property in Violation
#
# Serviced by Public Works
#
# this is for street maint,want the street to be repaired.
#
# PROPERTY WRITTEN UP FOR REHAB
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# ï¿½ï¿½ï¿½
#
# Serviced by Public Works
#
# ï¿½ï¿½ï¿½
#
# 01-26-2021 WROTE PROPERTY UP FOR REHAB
#
# back to mcsc forward to stormwater dept)
#
# NO PROGRESS, PROPERTY IS UNDER NEW OWNERSHIP
#
# PROPERTY IS BEING REHABBED
#
# Property in Violation
#
# 10.11.23 AT THE TIME OF INSPECTION PROPERTY WILL BE WRITTEN UP FOR CONDEMNATION TS FOLLOW-UP 11-26-23
#
# hearing held
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# VACANT PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHABILITATION.
#
# Property in Violation
#
# Property in Violation
#
# MS. CHRISTINA GREEN- 901-282-2423
#
# AT THE TIME OF INSPECTION A FINAL NOTICE WAS ISSUED FOR INOPERABLE VEHICLE.
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHABILITATION
#
# ISSUED VO TO THE OWNER: GANDY WILLIAM E JR Owner Address: 2612 BROWNING AVEï¿½ MEMPHIS TN 38114-4901
#
# Property in Violation
#
# Serviced by Public Works
#
# MAILED FM11-1 AND JW-RH 2/16/2024
#
# 3-12-2023.  JA
#
# High Weed VL
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# PROPERTY HAS BEEN WRITTEN UP FOR REHAB
#
# Property in Violation
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB
#
# PROPERTY HAS BEEN INSPECTEDAND WRITTEN UP FOR REHAB.
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# AT THE TIME OF INSPECTION VIOLATION NEEDS TO GO BACK TO MCSC FOR POLICES SERVICES DUE TO INOPERABLE VEHICLE PARKED ON THE STREET.
#
# Property in Violation
#
# 2-28-24 VEHICLES PARKED ON STREET
#
# HEARING RE-SET FOR 09/22/2021- MR. JERRY 901-386-0103
#
# Property in Violation
#
# Property in Violation
#
# Back to MCSC Storm water department issue.
#
# Property in Violation
#
# Property in Violation
#
# repaired months ago.
#
# WROTE UP PROPERTY FOR REHAB
#
# VACANT PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# Move to Condemnation Department
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# 2ND ATTEMPT TO INPUT DATA SPOKE TO OWNER, ELDERLY NEEDS HELP REMOVING CHATTLES
#
# Serviced by Public Works
#
# Property in Violation
#
# Property boarded and secured.
#
# NOTES 1.25.24 A VIOLATION ISSUED FOR JUNKY YARD FU 2.8.24
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR JUNKY YARD/BROKEN TREE BRANCHES ALL OVER BACKYARD WITH A COURT DATE OF 3/21/2024.
#
# 08/14/23/ AT THE TIME OF INSPECTION PROPERTY WAS IN COMPLIANCE
#
# BACK TO MCSC FOR TRANSFER
#
# cvom
#
# PRINTED AND MAILED 02/16/2024
#
# Property in Violation
#
# Property in Violation
#
# APPEAL FILED 01/08/2024
#
# Property in Violation
#
# . PROPERTY WAS INSPECTED AND WRITTEN UP FOR CONDEMNATION. Condemantion Hearing Date 2/24/2022 at 9:30am
#
# Property in Violation
#
# FINAL NOTICE ISSUED TO TENANT FOR CLEAN.
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# MR.GARY PRITCHARD- 901-685-5585-MANAGER
#
# PRINTED AND MAILED 2/21/2024
#
# Printed and mailed notice 02/16/2024 A. Coleman
#
# Property in Violation
#
# MOLD LIKE SUBSTANCE THROUGHOUT BATHROOM AND BEDROOM CLOSET. VIOLATION ISSUED TO OWNER AND PROPERTY MANAGEMENT
#
# 2-16 SEND TO SHELBY COUNTY HEALTH  Extended Stay Hotel
#
# ADRIAN HENDERSON- 901-205-6742- HE CALLED AND STATED THAT HIS PROPERTY IS IN GOOD CONDITION AND HE WILL NOT BE REHABBING HIS PROPERTY UNTIL THE NEXT DOOR PROPERTY IS REHABBED OR DEMOLISHED.
#
# BACK TO MCSC  MPD
#
# investigation REQUEST FROM SUBMITTED FOR OWNER INFO
#
# AT THE TIME OF INSPECTION AN INOPERABLE WHITE FORD VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# 01/07/2021 NO CHANGE ROTTEN WOOD STILL EXIT.
#
# Property in Violation
#
# Property in Violation
#
# INOPERABLE VEHICLE REFERRED BACK TO MCSC  - MPD
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# 90 days to repair
#
# Property in Violation
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHAB.
#
# TDOT Roadway - This roadway segment falls under the purview of the TN Dept. of Transportation. Please contact TDOT at (901) 684-5467 for additional information.
#
# Property in Violation
#
# Property in Violation
#
# ISSUED NOTICE TO CORRECT VIOLATION TO REPAIR OR REMOVE VEHICLE PARKED ON GRASS FOLLOW UP 7/12/22
#
# Property in Violation
#
# 10.25.23 AT THE TIME OF RECHECK NO PROGRESS SHOWN FINAL NOTICE ISSUED FOR YARD TS FOLLOW UP 11.9.23
#
# 3-8-24 PROPERTY IS A COMMERICIAL BUILDING
#
# DARRELL JONES- 609-254-7204- CAME FROM PHILADELPHIA, AND HE IS COMING UP WITH THE PLAN OF REHAB FOR THE PROPERTY,HE IS REPRESENTING EDWARD HARRIS
#
# AT THE TIME OF INSPECTION PROPERTY WAS IN COMPLIANCE.
#
# VENDOR HAS BEEN ASSIGNED FOR BOARD UP. 5-7 DAYS TO BE COMPLETED 12/11/23 -DDH
#
# FW TO STREET.
#
# Property in Violation
#
# VIOLATION ISSUED TO THE OWNER: ALDHUFRI OMAR A Owner Address:  547 VANCE AVEMEMPHIS TN 38126
#
# MS. LAQUITA JACKSON- PH: 662-342-3705
#
# TENANT HAS REMOVED TRAILER FROM YARD 2-12-24
#
# THIS PROPERTY WILL BE WRITTEN UP FOR REHAB
#
# JWRH UPDATED ON VCANT PROPERTY , FOLLOW UP 9/29/2022
#
# Apartments are regulated by the residential department.
#
# 10.25.23 AT THE TIME OF RECHECK NO PROGRESS SHOWN FINAL NOTICE ISSUED FOR YARD TS FOLLOW UP 11.9.23
#
# AT THE TIME OF INSPECTION A FINAL NOTICE WAS ISSUED FOR JUNKY YARD IN THE REAR OF PROPERTY.
#
# VEHICLE IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# WROTE UP PROPERTY TO BE REHABBED
#
# AT THE TIME OF INSPECTION PROGRESS WAS MADE WITH A NEW FOLLOW-UP DATE OF 3/13/2024 FOR COMPLIANCE.
#
# Property in Violation
#
# posted
#
# PROPERTY HAS BEEN WRITTEN UP FOR REHAB
#
# ID2 MAILED 01/10/2023
#
# AT THE TIME OF INSPECTION A NOTICE TO IMPOUND WAS ISSUED FOR INOPERABLE VEHICLE.
#
# Property in Violation
#
# FW TO REPAIR
#
# 1-10-24 PROPERTY IS A COMMERICIAL BUILDING
#
# PROPERTY WRITTEN UP FOR CONDEMNATION
#
# DAUGHTER PHONE 901-512-2664
#
# Hearing Rescheduled August 22,2019
#
# TS-O 12/06/2023 TS-R 12/07/2023 Condemnation Hearing January 25, 2024 @ 9:30 am
#
# AT THE TIME OF INSPECTION THE DAMAGED VEHICLE WAS PARKED ON THE STREET AND SENT BACK TO MCSC.
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR JUNKY YARD/OPEN STORAGE.
#
# Property in Violation
#
# Property in Violation
#
# PARNELL P WIGGINS- 901-517-5688- SON
#
# AT THE TIME OF INSPECTION A NOTICE WAS ISSUED FOR A JUNKY YARD; FOLLOW UP DATED 11-8-22
#
# Property in Violation
#
# Property in Violation
#
# SHERON DANNY- 901-490-1129
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED FOR HIGH GRASS AND WEEDS/OPEN STORAGE AND PARKING ON GRASS.
#
# ï¿½ï¿½ï¿½
#
# PROPERTY HAS BEEN INSPECTED AND WRITTEN UP FOR REHAB.
#
# Back To MCSC forward to Shelby County
#
# Second Intent to demolish letter mailed 08/15/2023
#
# 11-14-23 ISSUED A NOTICE TO CORRECT VIOLATION TO REMOVE JUNK AND DEBRIS FROM THE PROPERTY
#
# Property in Violation
#
# Property in Violation
#
# Serviced by Public Works
#
# Property in Violation
#
# Hearing Rescheduled August 22, 2019
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# AT TIME OF FOLLOW UP INSPECTION THERE WAS NO PROGRESS MADE SHE STATED CAR BELONGED T DECEASED HUSBAND NEED MORE TIME
#
# Property in Violation
#
# PROPERTY OWNED BY MR.MCCOMB 9015171149 / WRITE UP COMPLETED AND SUBMITTED
#
# POSTED MAILER ON 10/3/2023
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# OPERABLE 18 WHEELER ON THE STREET WAS SENT BACK TO MCSC MPD
#
# Property in Violation
#
# Property in Violation
#
# Active NPA case
#
# AT THE TIME OF INSPECTION A FINAL NOTICE WAS ISSUED FOR INOPERABLE VEHICLE AND OPEN STORAGE ON GRASS.
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER ERIC MHOON
#
# Property in Violation
#
# PENDING SHELBY COUNTY TAX SALE
#
# Property in Violation
#
# PRIVATE PROPERTY ISSUE, PER L. KEE
#
# Property in Violation
#
# 2/1/24 NOTES AT THE TIME OF INSPECTION A VIOLATION ISSUED FOR ROOF DMAGE  FU 03/01/24
#
# ANTONIO REBOLLAR- 901-214-4850- 12/20/2019
#
# AT THE TIME OF INSPECTION VIOLATION WAS CORRECTED.
#
# Property in Violation
#
# MS. MARILYN- 901-485-6234
#
# Property in Violation
#
# Property in Violation
#
# NOTICE VIOLATION WAS ISSUED FOR APPLIANCE AND JUNKY YARD. FOLLOW-UP 6-7-23
#
# 09/23/22 SEE SR# 5912342
#
# NEW OWNER- OTIS FOX
#
# Property in Violation
#
# PRINTED AND  MAILED 02/20/2024
#
# REFER TO MPD
#
# 10-17-2023 BACK TO MCSC,  REFER TO GROUNDS DEPT (JN)
#
# INOPERABLE VEHICLE ON THE STREET WAS REFERRED BACK TO MCSC MPD
#
# Remove junk cars clear the street from cars in disrepair.
#
# Property in Violation
#
# MR. ELLIOT WILLIAMS- 407-968-3650
#
# Property in Violation
#
# Residential Property
#
# refer to shelby county code hotel property
#
# Property in Violation
#
# Property in Violation
#
# 11-2-21 ,10-26-21 WRITE UP
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# AT THE TIME OF INSPECTION THE VACANT LOT HAS DEBRIS FROM PREVIOUS STRUCTURE AND OVERGROWTH.
#
# Property in Violation
#
# MS. MARJORIE BOTTERON- 704-305-5715
#
# SIDE DOOR HAS A BOARD ON IT BUT IS NOT SECURED.
#
# ï¿½ï¿½ï¿½
#
# 9.27.2022, SHELBY COUNTY OWNED PROPERTY.
#
# SEASONAL VIOLATION
#
# WROTE UP PROPERTY TO BE REHABBED
#
# Owner granted 90 days repair
#
# 01-23-2021 ISSUED VIOLATION TO BOARD AND SECURE. F/U 02-06-2021
#
# ï¿½ï¿½ï¿½
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# Owner granted 90 days repair
#
# Property in Violation
#
# Property in Violation
#
# 901-766-0800- REPRESENTATIVE NUMBER- THEIR NEW MAILING ADDRESS IS 4289 HIGH PLAINS RD, BARTLETT, TN 38135
#
# ï¿½ï¿½ï¿½
#
# refer to drain.  inlet cover is missing.
#
# AT THE TIME OF INSPECTION THERE WAS NO VIOLATION.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# HEARING RE-SCHEDULED FOR 10/30/2018- MA
#
# PROPERTY WRITTEN UP FOR REHAB
#
# NOTICE ISSUED TO REPAIR POTHOLES IN PARKING LOT
#
# I TALKED WITH THE OWNER OF PROPERTY AND ASKED FOR A LITTLE MORE TIME
#
# Property in Violation
#
# SR 5272660 AKA SR 4088108
#
# HYMON LUTHER- 901-644-5310
#
# HEARING RE-SCHEDULED FOR 01/31/2019
#
# Property in Violation
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½HAYNES-SANFORD HOLDINGS
# Owner Address:
# ï¿½4173 ELVIS PRESLEY BLVD ï¿½
# MEMPHISï¿½TNï¿½38116
#
# PROJECT MANAGER- 901-494-0284
#
# Property in Violation
#
# MS. BRENDA WALLS- 901-372-1160
#
# Property in Violation
#
# Property in Violation
#
# PRINTED AND MAILED 3/18/2024 Z.W.
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR OPEN STORAGE/JUNKY YARD FOR 3/21/2024.
#
# WROTE UP PROPERTY TO BE REHABBED
#
# TRAVIS MCGLOTHIAN- 901-604-2795
#
# KATHIE NICKELSON- 901-581-8498
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB
#
# Property on hold for 90 days. Per Code Enforcement Prosecutor W. Davis
#
# AT THE TIME OF INSPECTION AN INOPERABLE BLACK CHEVY IMPALA IS PARKED ON THE STREET.  NEEDS TO GO BACK TO MCSC.
#
# WROTE UP PROPERTY TO BE REHABBED
#
# ISSUED NOTICE TO CORRECT TO CLEAN REAR PORCH
#
# ISSUED VIOLATION TO THE OWNER: CARRIE
#
# Cut grass and high weeds
#
# Property in Violation
#
# p/u
#
# CITY PARK
#
# SEE SR#5946696
#
# THIS PROPERTY IS BEING WRITTEN UP FOR CONDEMNATION
#
# Refer to 2776830
#
# Property in Violation
#
# Property in Violation
#
# DERELICT STRUCTURE VACANT PROPERTY / CREATED WRITEUP
#
# NOTICE TO CORRECT ISSUED FOR NO UTILITIES
#
# PRINTED AND MAILED 02/20/2024
#
# NOTICE REHAB
#
# Back to mcsc forward to solid waste 2-2-24
#
# COMMERCIAL PROPERTY
#
# 10.17.23 AT THE TIME OF RECHECK TENANT HAS LEAKS IN KITCHEN AND RESTROOM F/U 10.31.23
#
# CALVIN JOINER- 901-581-4161
#
# Property in Violation
#
# Property in Violation
#
# Contractor Everett Doty 9016019196
#
# Property in Violation
#
# Rehab building
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# OTIS MCKINNEY- 901-490-4686- MAILING ADDRESS 4343 COTTONWOOD RD , MEMPHIS, TN 38118
#
# Court Date 10/31/2022@ 9:00am.
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB
#
# RESIDENTIAL PROPERTY
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# Back To MCSC forward to Shelby County Code
#
# NOTICE TO CORRECT ISSUED FOR INTERIOR DAMAGES
#
# Property in Violation
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# 10/16/23 At time of reinspection auto was gone.
#
# Property in Violation
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# 11-27-2023; SENT TO MCSC
#
# VEHICLE ON THE STREET WAS REFER BACK TO MCSC MPD
#
# Property in violation, high grass mainly in backyard
#
# 1-25-23 ISSUED A FINAL NOTICE
#
# NO FURTHER ACTIONS WILL BE TAKEN AT THIS TIME
#
# 1/23/24 NOH AT TIME OF INSPECTION F/U 1/24/24;    1/24/24  ISSUED VOM TO MAKE REPAIRS TO UNIT F/U 2/7/24; PRINTED AND MAILED 02/01/2024 2-15-24 NOONE HOME
#
# Property in Violation
#
# Property in Violation
#
# OWNER FILED CD APPEAL 01/12/2024
#
# PROPERTY WAS INSPECTED AND WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# FILE GIVEN BACK TO MR. TUMBRINK ON 03/04/2020- PROPERTY UNDER NEW OWNERSHIP- FENELON MENDONCA NETO
#
# WATER HEATER WAS REPLACED.
#
# INOPERABLE VEHICLE REFERRED TO MPD
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR HIGH GRASS AND WEEDS.
#
# Property in Violation
#
# Property in Violation
#
# PRINTED AND MAILED 2/14/2024 Z.WILLIAMS
#
# Monitoring. The owner was given more time to finalize repairs.
#
# Property in Violation
#
# Property in Violation
#
# 4-17-2023 issued a final not on junky yard (tires, totes and workout bench in rear yard (yellow door tag with phone numbers issued.follow up 4/24/2023 or issue a summons
#
# Property in Violation
#
# MLGW charged $50.00
#
# VACANT PROPERTY WRITTEN UP FOR REHAB.
#
# Property in Violation
#
# 10-17-2023 AT THE TIME OF INSPECTION NO ONE WAS HOME 1ST ATTEMPT FOLLOW-UP DATE 11-1-23
#
# INVESTIGATION REQUEST FORM SEEKING OWNERSHIP INFORMATION REQUESTED
#
# Failed to appear despite of the court dismissal letter. Property refered back to CD.
#
# Property in Violation
#
# DEBRA REDUS- 901-240-1745
#
# Property in Violation
#
# Property in Violation
#
# 11-2-23 vehicles on street send to mpd
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR VEHICLES PARKED ON GRASS.
#
# Property in Violation
#
# COMMERCIAL PROPERTY
#
# Rehab and cut and maintain grass
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED FOR OPEN STORAGE AND INOPERABLE VEHICLES.
#
# Property in Violation
#
# BACK TO MCSC FOWARD TO COMMERICAL CODE
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# NEEDS TO GO BACK TO MCSC.
#
# 1-25-23 ISSUED A FINAL NOTICE FOLLOW UP 2-8-23
#
# CAROL LEE- 901-502-5673-  EXECUTIVE ON WILL FOR DECEASED OWNER
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# SEND TO POLICE
#
# ï¿½ï¿½ï¿½
#
# 10.30.23 AT THE TIME OF RECHECK REPAIRS HAVE NOT BEEN COMPLETED. MANAGER OF PROPERTY HAS BEEN GIVEN EXTENSION. REPAIRS STILL NOT COMPLETED WORKING ON SCHEDULING PLUMBER PER MANAGEMENT
#
# Property in Violation
#
# Property in Violation
#
# SHELBY COUNTY PROPERTY - BACK TO MCSC
#
# MR. WILLIE BUTLER- 901-643-2897
#
# Duplicate of 5966832
#
# SUSAN KENT- 901-647-4732
#
# Property in Violation
#
# case dismissed
#
# Property in Violation
#
# CRYSTAL WINDLESS- 901-881-7558- SHE STATED THAT SHE ALREADY FINISHED CLEANING DEBRIS, AND MOST OF THE WORK ON THE PROPERTY, CURRENTLY WORKING ON THE CARPORT AREA.
#
# Property in Violation
#
# Property was written up for rehab on 10/1/21 follow up date 11/15/21
#
# PRINTED AND MAILED 02/20/2024
#
# WROTE UP PROPERTY TO BE REHABBED
#
# NEW OWNER
#
# ISSUED VIOLATION TO THE OWNER
#
# Property in Violation
#
# WRITE UP COMPLETED AND SUBMITTED
#
# BACK TO MCSC MPD
#
# AT THE TIME OF INSPECTION SENT BACK TO MCSC FOR  POLICES SERVICES DUE TO INOPERABLE VEHICLE PARKED ON STREET.
#
# Property in Violation
#
# Property in Violation
#
# High grass was cut.
#
# Property in Violation
#
# please refer to commerical code.
#
# 10-19-23 TENANTS HAVE MADE PROGRESS, GIVEN ENTENDED TIME
#
# refer to street this is a bucking street
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR INOPERABLE VEHICLE.
#
# ISSUED VIOLATION TO THE OWNER: ROBERT E. DEIBE / 1255 FITE RD, MILLINGTON TN 38053-
#
# Property in Violation
#
# Intent to demolish letter mailed to owner of record because of failed appeal 11/16/2023
#
# COMMERCIAL
#
# 09-14-2021 ISSUED VIOLATION TO REPAIR PARKING LOT. F/U 10-14-2021
#
# PRINTED AND MAILED 02/20/2024
#
# AT THE TIME OF INSPECTION VIOLATION NEEDS TO GO BACK TO MCSC DUE TO COMPLAINT ON 2 INOPERABLE VEHICLES PARKED ON THE STREET.
#
# ï¿½ï¿½ï¿½
#
# AT THE TIME OF INSPECTION A FINAL NOTICE TO CORRECT WAS ISSUED FOR DEBRIS ON THE REVERSE FRONTAGE.
#
# PRINTED AND MAILED 2/16/2024 Z.WILLIAMS
#
# ...
#
# ï¿½ï¿½ï¿½
#
# Property in Violation
#
# Property in Violation
#
# AT THE TIME OF INSPECTION AN INOPERABLE BLACK CHEVY IMPALA IS PARKED ON THE STREET.� NEEDS TO GO BACK TO MCSC.
#
# Occupied no violation
#
# Property in Violation
#
# Work progress. Inspector will monitor until repairs are complete.
#
# Property in Violation
#
# MR. JONES- 901- 649-4068
#
# Property in Violation
#
# occupied-no violation
#
# Property in Violation
#
# ISSUED VIOLATION TO THE OWNER:ï¿½ARIJE WESLEYOwner Address:ï¿½8419WOOD SHADOWS LN ï¿½CORDOVAï¿½TNï¿½38018-6466
#
# Condemnation hearing January 25, 2024 @ 9:30 am
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR INOPERABLE VEHICLES AND PARKING ON THE GRASS.
#
# state route referr to TDOT
#
# 10.25.23 AT THE TIME OF RECHECK NO PROGRESS SHOWN FINAL NOTICE ISSUED FOR YARD TS FOLLOW UP 11.9.23
#
# 01/24/24 At time of reinspection all is ok.
#
# Property in Violation
#
# 07-22-2021 ISSUED VIOLATION TO REPAIR POTHOLES IN PARKING LOT. FOLLOW UP DATE IS 08-21-2021. THE STORAGE CONTAINER IS ON A DIFFERENT PARCEL, AND NEEDS TO BE ADDRESSED BY COUNTY CODE.
#
# T THE TIME OF INSPECTION VIOLATION NEEDS TO GO BACK TO MCSC FOR POLICES SERVICES DUE TO TRAILER PARKED ON THE STREET.
#
# 901-634-3926
#
# SR# 5491804.  f/u 1/4/22
#
# No Potholes found - Contact 311 with more information
#
# Property in Violation
#
# No progress on the vacant property as of the hearing from Ms. Jackson : property is in the same condition
#
# Property in Violation
#
# property secured by the city
#
# Property in Violation
#
# INOPERABLE VEHICLE ON THE STREET WAS REFERRED BACK TO MCSC MPD
#
# ISSUED VIOLATION TO THE OWNER:ï¿½IBRAHIM, FOZIA AND MEFTHUA SALIHOwner Address:ï¿½3178 OLD HORN LAKE RD ï¿½MEMPHISï¿½TNï¿½38109
#
# VENDOR FOR BOARD UP HAS BEEN ASSIGNED 5-7 DAYS TO BE COMPLETED 11/21/2023-DDH
#
# PROPERTY IS STILL BOARDED AND SECURED BUT NO ATTEMPTS AT REPAIRS WERE OBSERVED. A DNO MUST NOT OCCUPY PLACARD WERE POSTED ALONG WITH A RETURNED LETTER. A NPF11 #1 WAS REQUESTED TO BE MAILED.  F/U 6-28-18.
#
# Property in Violation
#
# Ms. Charletta Green- 951-347-4855
#
# REFER TO SHELBY COUNTY CODE
#
# 7-18-2022.  WROTE HOUSE UO FOR REHAB
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# MS. ARTAVIA WILSON- 702-339-7883
#
# Rehab building and install safeguarding protective covering around unfenced perimeter.
#
# jwrh
#
# Property in Violation
#
# AT THE TIME OF INSPECTION A NOTICE TO CORRECT WAS ISSUED FOR VEHICLE/TRAILER PARKED ON GRASS.
# PRINTED AND MAILED 2/14/2024 Z.WILLIAMS
#
# Property in Violation
#
# back to mcsc, housing
#
# Back to MCSC not a commercial code issue.
#
# Property in Violation
#
# Property in Violation
#
# Property in Violation
#
# Serviced by Public Works
#
# THIS IS NOT A SHELBY COUNTY PROPERTY
#
# Property in Violation
#
# Property in Violation
#
# ISSUED NOTICE TO REPAIR POT HOLE THROUGHOUT PARKING LOT
#
# AT THE TIME OF INSPECTION VIOLATION WAS CORRECTED.
#
# Npa case set for 10/21/21 at 10:00am
#
# COURT SUMMONS ISSUED FOR FAILURE TO REMOVE HIGH GRASS AND WEEDS
#
# Active NPA Case
#
# Active NPA case (Wooddale Condos)
#
# COURT SUMMONS ISSUED F/U  6/16
#
# CD APPEAL COURT CASE DISMISSED 12/12/2023. REFERRED TO THE NEIGHBORHOOD PRESERVATION ACT PROCESS.
#
# AT THE TIME OF INSPECTION A  COURT SUMMONS WAS ISSUED FOR  3-10-23.
#
# OWNER OF PROPERTY HAS BEEN COITED TO COURT FOR NOT CLEANING JUNK IN BACKYARD
#
# CHARLES WESSEH-  PH: 215-406-6035
#
# COURT SUMMONS WILL BE ISSUED TUESDAY 12/13- PACKET ALREADY PUT TOGETHER
#
# Active NPA case
#
# Active NPA Case
#
# Active NPA Case
#
# Active NPA case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR HIGH GRASS AND WEEDS/JUNKY YARD/OPEN STORAGE FOR 11/16/2023.
#
# ID2 Notice Mailed to listed owner
#
# court SUMMONS issued 10.19.23
#
# 10/7/2022 Failure to comply to repair water leak
#
# Active NPA case
#
# COURT DATE 8-17-2022
#
# PER INSPECTOR WALKER
#
# Owner to Continue work progress
#
# CD case dismissed 11/28/2023. The subject parcel has been referred to the Neighborhood Preservation Act process.
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR NON-COMPLIANCE OF JUNKY YARD/OPEN STORAGE ON 12/6/2023.
#
# Active NPA case
#
# COURT SUMMONS ISSUED
#
# Active NPA Case
#
# ID2 mailed 03/08/2023
#
# Repeat Offender
#
# AT THE TIME OF INSPECTION A FINAL NOTICE WAS ISSUED FOR HIGH GRASS AND WEEDS AND OPEN STORAGE.
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FORD 8-25-23
#
# MS. KARINA AND PATRICIA FERNANDEZ- 901-319-7159 AND 901-552-0704.
#
# PROPERTY HAS BENN WRITTEN UP FOR REHAB
#
# Duplicate of 5984116
#
# Active NPA case (Wooddale Condos)
#
# Active NPA Case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR JUNKY YARD/OPEN STORAGE ON 11/15/2023
#
# MS.TAMEKA PH:901-326-5527- HEARING RE-SET FOR 12/12/2019
#
# LARGE AMOUNT OF CHATTELS IN THE REAR OF THE PROPERTY.
#
# Active NPA case
#
# Administrative Referral
#
# Property in Violation
#
# Active NPA case
#
# Property in Violation
#
# ï¿½ï¿½ï¿½
#
# Active NPA case (Wooddale Condos)
#
# Property in Violation
#
# Property in Violation
#
# Active NPA case
#
# Active NPA case
#
# ID2 MAILED 10/04/2023
#
# Active NPA case
#
# ï¿½ï¿½ï¿½
#
# Active NPA Case
#
# HEARING RE-SCHEDULED FOR 04/17/2019- PH:901-232-1581-CELL
#
# closed vob , fence pieces repaired
#
# in-compliance
#
# AT THE TIME OF RECHECK THIS PROPERTY WAS NOT IN COMPLIANCE AND A SUMMONS WAS ISSUED FOR 11-17-2021.
#
# BENCH WARRANT
#
# BENCH WARRANT
#
# Active NPA case
#
# Active NPA case
#
# Active NPA case
#
# FW TO REPAIR
#
# Active NPA case
#
# Active NPA Case
#
# ï¿½ï¿½ï¿½ï¿½ï¿½
#
# NPA COURT CASE DISMISSED 10/17/2023. CITY OF MEMPHIS WILL SUSPEND DEMOLITION AND REFER THE PROPERTY TO THE NPA PROCESS.
#
# Active NPA Case
#
# Active NPA case (Wooddale Condos)
#
# Active NPA case
#
# Active NPA case
#
# Remove graffiti from property
#
# Active NPA case
#
# Active NPA case
#
# Active NPA case (Wooddale Condos)
#
# Active NPA case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR NON-COMPLIANCE. A COURT SUNNIES WAS ISSUED FOR 2/15/2024
#
# 10.5.2023 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED FOR YARD INOPERABLE VEHICLES TS FOLLOW UP 10.19.23
#
# Administrative Referral
#
# Active NPA case
#
# Active NPA Case
#
# Active NPA case
#
# Active NPA Case
#
# ï¿½ï¿½ï¿½
#
# BENCH WARRANT
#
# FW TO REPAIR
#
# active npa case
#
# NOTICE ISSUED TO CLEAN JUNKY EXTERIOR PROPERTY AND REMOVE INOPERABLE VEHICLES
#
# COURT SUMONS ISSUED
#
# NOTICE ISSUED TO CLEAN JUNKY EXTERIOR PROPERTY, REMOVE INOPERABLE VEHICLES, CEASE PARKING IN YARD AND CEASE PREFORMING MAJOR VEHICLE REPAIR.
#
# Active NPA Case
#
# Please refer to 4692218
#
# ISSUED VIOLATION TO THE OWNER:ï¿½HALEY THELDRIDGE L & MARIEOwner Address:ï¿½9379 LAKE BRIDGE DR ï¿½LAKELANDï¿½TNï¿½38002
#
# Active NPA Case
#
# Active NPA Case
#
# AT THE TIME OF INSPECTION DUE TO NONCOMPLIANCE A COURT SUMMONS WAS ISSUED FOR 2/15/2024.
#
# Dismissed
#
# ï¿½ï¿½ï¿½
#
# NICHOLE CROSS- 240-305-5645
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR FAILURE TO COMPLY TO VIOLATIONS WITH A COURT SUMMONS DATE OF 11/16/2023
#
# AKREM SABEHA- 901-600-6153- THE OWNER CALLED AND STTAED THAT HE WANTS TO REPAIR THE HOUSE, AND HE DON'T WANT TO DEMOLISH IT- MA
#
# Active NPA case
#
# 901-301-9250-GLORIA JONES-THE OWNER - NPA COURT DATE SET FOR 1/25/2024 @ 1:30PM
#
# WPP PER INSPECTOR R.WITTER
#
# 901-830-9465 Stacey Sanders. tenant
#
# Active NPA Case
#
# Administrative Referral
#
# BENCH WARRANT $50 FINE X 1
#
# AT THE TIME OF INSPECTION A COURT SUMMONS IS ISSUED FOR DAMAGED FENCE FOR COURT DATE 1/31/2024.
#
# Active NPA case
#
# Duplicates of 5293726
#
# Active NPA case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR NON-COMPLIANCE ON 11-16-2023 FOR HIGH GRASS AND WEEDS.
#
# THE PROPERTY OWNER SEEKING PARTNERSHIP WITH THE CITY TO ASSIST WITH FUNDING / WE NEED REHAB PLAN OR DEMO PLAN
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR JUNKY YARD/OPEN STORAGE.
#
# CD APPEAL COURT CASE DISMISSED 9/19/2023. SUFFICIENT PROGESS. REFERRED TO THE NEIGHBORHOOD PRESERVATION ACT PROCESS
#
# PROPERTY NEEDS BOARD UP
#
# 901-218-4439- OWNER'S DAUGHTER MS. LILIAN
#
# SR IS THE CONTINUATION OF 2832812
#
# COURT DATE 2/7/2022, case closed 3-7-22
#
# NPA COURT CASE DISMISSED 10/17/2023. CITY OF MEMPHIS WILL SUSPEND DEMOLITION AND REFER THE PROPERTY TO THE NPA PROCESS.
#
# PROPERTY IS BEING WRITTEN UP FOR REHAB
#
# NOTES 8.26.23 AT THE TIME OF RECHECK FINAL NOTICE HAS BEEN ISSUED TS FOLLOW UP 9.9.23
#
# Active NPA case
#
# ï¿½ï¿½ï¿½ï¿½ï¿½
#
# Active NPA case
#
# Shelby County Owned Property. Please contact the Shelby County Land Bank at 901-222-2575 for further information.
#
# BRIAN MORRIS- 901-265-4464- HEARING RE-SET FOR 02/13/2020
#
# NPA court date set for 10/5/2023 at 10:00AM
#
# 10.25.23 AT THE TIME OF RECHECK COURT SUMMONS ISSUED TO OWNER F/U 12.7.23
#
# Active Npa Case
#
# Somerset Apartments
#
# Active NPA case
#
# COURT SUMMONS ISSUED F/U 10/19
#
# NPA COURT DATE SET FOR 3/14/2024 @ 1:30PM
#
# AT THE TIME OF INSPECTION OWNER FAILED TO ABATE MOLD-LIKE SUBSTANCES RESULTING IN COURT SUMMONS ISSUED FOR 10/16/2023.
#
# COURT SUMMONS ISSUED F/U 10/19
#
# Active NPA Case
#
# CD appeal court case dismissed 11/7/2023. Referred the property to the Neighborhood Preservation Act process
#
# THE PROPERTY OWNER SEEKING PARTNERSHIP WITH THE CITY TO ASSIST WITH FUNDING / WE NEED REHAB PLAN OR DEMO PLAN
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR NON-COMPLIANCE WITH A COURT SUMMONS DATE FOR 2/15/2024.
#
# Bill Dismissed, no vendir befire photos 12/26/2023
#
# ï¿½ï¿½ï¿½ï¿½ï¿½
#
# 11.2.23 AT THE TIME OF RECHECK NO PROGRESS SHOWN FINAL NOTICE ISSUED FOR YARD TS FOLLOW UP 11.16.23
#
# NOTICE TO CORRECT ISSUED TO REPAIR WATER LEAK
#
# Active NPA Case
#
# AT TIME OF INSPECTION PROPERTY WAS NOT A DERELICT STRUCTURE.
#
# ID2 MAILED TO NEW OWNER 10/10/2022
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR JUNKY YARD/ INOPERABLE VEHICLES FOR 11/15/2023.
#
# BENCH WARRANT $50 FINE X 1
#
# Bench Warrant
#
# Active Npa Case
#
# PROPERTY WRITTEN UP FOR REHAB.
#
# ISSUED A VIOLATION TO REMOVE ALL INOPERABLE VEHICLE FROM THE FRONT AND BACK YARD OF THE PROPERTY REMOVE JUNK, TRASH AND DEBRIS FROM THE PROPERTY
#
# Active NPA Case
#
# PROPERTY WAS WRITTEN UP FOR REHAB
#
# A summon was issued to the owner
#
# Active NPA Case
#
# Active NPA Case
#
# Active NPA case (Wooddale Condos)
#
# Active NPA case (Wooddale Condos)
#
# Property in Violation
#
# deliver 1 cart
#
# CD COURT CASE DISMISSED 9/26/2023. SUFFICIENT PROGRESS MADE. REFERRED TO NPA PROCESS.
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR JUNKY YARD ON 11/8/2023.
#
# ï¿½ï¿½ï¿½ï¿½ï¿½
#
# ï¿½ï¿½ï¿½
#
# Active NPA Case
#
# CHARGES DIMISSED VENDOR SERVICED WRONG LOCATION 12.12.2023
#
# Active NPA Case
#
# Active NPA case
#
# WRONG ADRRESS
#
# Active NPA case
#
# AT THE TIME OF RECHECK THE PROPERTY WAS NOT IN COMPLIANCE AND A SUMMONS WAS ISSUED FOR 11-17-2021.
#
# Active NPA case
#
# Active NPA Case
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR INOPERABLE VEHICLE AND OPEN STORAGE UNDER CARPORT FOR 11/16/2023.
#
# Active NPA case
#
# COURT SUMMONS ISSUED F/U  7/21
#
# MOST ISSUES REPAIRED AWAITING FOR THEM TO FINISH THE ELECTRICAL ISSUES
#
# AT THE TIME OF INSPECTION A SUMMONS WAS ISSUED  FOR 3-17-23.
#
# Active NPA case
#
# Active Npa Case; on 7-31-19 Made inspection & No Progress Shown.
#
# original court date 11-1-2021
#
# COURT DATE 10-24-2022
#
# 901-297-6045 ms banyon
#
# AREA INSPECTOR HAS PLACED OWNER IN COURT FOR JUNKY YARD AND HIGH WEEDS
#
# AT THE TIME OF INSPECTION ON 11.27.23 NO PROGRESS: PROPERTY IS IN THE SAME CONDITION AS THE LAST COURT SETTING.  CHATTEL STORED UNDERNEATH THE CARPORT AND REAR. OTHER VIOLATIONS SUCH AS HIGH GRASS AND WEEDS IN THE REAR UN - CITIED.
#
# 04/26/20 REMOVE OR REPAIR ALL INOPERABLE VEHICLES CLEAN ALL TRASH AND DEBRIS FROM PROPERTY WITHIN F/U 05/26/20 FINAL NOTICE ISSUED FAILURE TO COMPLY WILL RESULT IN COURT ORDER ISSUED
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR 9-1-2023.
#
# Active NPA case
#
# Active NPA Case
#
# Active NPA Case
#
# 6.29.2023, AT THE TIME OF INSPECTION  THERE WAS NO PROGRESS MADE HVAC STILL NOT FUNCTIONING
#
# BENCH WARRANT
#
# COURT DATE 11-7-2022
#
# NPA COURT DATE SET FOR 12/14/2023 @ 10:00AM
#
# COURT ORDERED BOARD UP ASSIGNED TO BE COMPLETED 5-7 DAYS 10/19/2023-DDH Private (Non-Active) City Case -  NPA court date set for 1/25/2024 at 1:30 PM
#
# Active NPA Case
#
# Active NPA case
#
# NOTICE TO CORRECT ISSUED TO REPAIR ALL INTERIOR DAMAGES IN WORKMANLIKE
#
# BENCH WARRANT $50 ISSUED
#
# AT THE TIME OF MY FOLLOW-UP INSPECTION THE PROPERTY WAS BEING MAINTAINED AND EVIDENCE OF WORK PROGRESS EXIST / REACHING OUT TO THE OWNER FOR A PLAN OF RENOVATIONS
#
# COURT SUMMONS ISSUED
#
# PROPERTY IN NEED OF REHAB
#
# NPA COURT DATE SET FOR 1/18/2024 @ 10:00AM
#
# Active NPA case ( Wooddale Condos)
#
# Active NPA case
#
# ï¿½ï¿½ï¿½
#
# court case continued
#
# 02-21-2023 AT THE TIME OF THE FOLLOW UP THERE WERE NO PROGRESS
#
# Justified, Active already file
#
# preparing to cite to court
#
# no violation
#
# Please refer to 5421216
#
# 901-513-1354 KENNY JONES
#
# 8-15-23 SUMMONS POSTED FOR FAILURE TO REPAIR OR REMOVE INOPERABLE VEHICLES, VEHICLES PARKED ON GRASS F/U 9-22-23
#
# NOTICE ISSUED TO REPAIR CRACKED FOUNDATION AND ABATE MICE INFESTATION
#
# ï¿½ï¿½ï¿½ï¿½ï¿½
#
# 8-17-23 SUMMONS ISSUED FOR FAILURE TO MAINTAIN EXTERIOR OF PROPERTY F/U 9-29-23
#
# DEBORAH FRANKLIN- 901-282-0541 NPA COURT DATE SET FOR 12/7/2023 @ 10:00AM
#
# active npa case
#
# NPA COURT DATE SET FOR 9/28/2023 @ 10:00AM
#
# Bench Warrant
#
# original court date 11-1-2021
#
# VACANT PROPERTY STILL IN DISREPAIR.
#
# court summons issued
#
# Active NPA case
#
# 10-11-22 ISSUED COURT SUMMON TO OWNER NO PROGRESS AT TIME OF RECHECK FU 11-2-22
#
# Active NPA case
#
# Active NPA Case
#
# Active NPA case (Wooddale Condos)
#
# WROTE UP PROPERTY TO BE REHABBED
#
# 02/09/24:JUSTIFIED ACTION SR 5353066
#
# NOTICE ISSUED TO REMOVE INOPERABLE VEHICLES, REMOVE BOAT AND TRAILER FROM STREET AND REMOVE EXCESSIVE AMOUNT OF VEHICLES
#
# MR. DURRELL DOWELL- 901-303-4713  NPA COURT DATE SET FOR 1/18/2024 @ 10:00AM
#
# there is a dog on the property in the rear under the blue trailer.
#
# BENCH WARRANT $50 fine x1
#
# NPA COURT DATE SET FOR 1/18/2024 @ 10:00AM
#
# FW TO REPAIR
#
# CD case dismissed 11/28/2023. The subject parcel has been referred to the Neighborhood Preservation Act process.
#
# AT THE TIME OF INSPECTION A COURT SUMMONS WAS ISSUED FOR OPEN STORAGE ON 1/18/2024
#
# Administrative Referral
#
# BENCH WARRANT
#
# Active NPA Case
#
# Chuch property
#
# MR. MURDOCH- 901-650-8989- HE CALLED AND SAID THAT HE WILL BE WORKING ON THE PROPERTY
#
# Active NPA Case
#
# BENCH WARRANT $50 FINE X 1
#
# NOTICE TO CORRECT ISSUED FOLLOW UP DATE 05-24-2023
#
# Active NPA case
#
# Active NPA Case (Fox Hollow)
#
# Active NPA Case
#
# VENDOR HAS BEEN ASSIGNED FOR BOARD UP. 5-7 DAYS TO BE COMPLETED 12/11/23 -DDH
#
# COURT SUMMONS ISSUED
#
# Active NPA case
#
# PH # 901-237-9530
#
# 9.18.2023 ISSUED COURT SUMMONS
#
# JABARI MOORE- 972-814-1361- HE CALLED ON 10/05/2021 AND STATED THAT HE WANTS TO DEMOLISH THE PROPERTY IN NEXT 6 MONTHS. HE CUT THE YARDS AND WILL BE KEEPING IT MAINTAINED.
#
# Active Npa Case
#
# EUGENE TIBBS- 202-441-5765- OWNER'S SON   NPA COURT DATE SET FOR 10/19/2023 @ 10:00AM
#
# MR. WILLIE HILL- 901-490-6969
#
# Active NPA Case
#
# COURT DATE 11-7-2022
#
# Active NPA Case
#
# JUNKY YARD, INOPERABLE VEHICLES ARE ON SIDE YARD. VIOLATION ISSUED TO TENANT.  AND MAILED TO OWNER
#
# Bill Reduced from $1,100.00 to $880.00 - 12/15/2023
#
# NPA COURT DATE SET FOR 11/2/2023 @ 1:30PM
#
# active npa case
#
# Property in Violation
#
# PAMELA PRICE 901-708-0091
#
# COURT SUMMONS ISSUED
#
# Active NPA Case
#
# 10.5.2023 AT THE TIME OF INSPECTION VIOLATION WAS ISSUED FOR YARD INOPERABLE VEHICLES TS FOLLOW UP 10.19.23
#
# 1-12-24 OWNER FAILED TO MAINTAIN PROPERTY, A COURT SUMMONS WAS ISSUED WITH A DATE OF 1-31-24
#
# Active NPA Case
#
# Building write up for demo
#
# JW-DM
#
# PROPERTY IN NEED OH REHAB
#
# Active NPA case
#
# REFER TO GROUNDS
#
# Active NPA case
#
# Active NPA case
#
# 10-17-2023.  ISSUED A COURT SUMMONS
#
# Active NPA case
#
# Administrative NPA Referral
#
# NPA Administrative Referral
#
# Property in Violation
#
# MS. LISA RUPLE (MANAGER FOR O'S REALTY) STATED THAT THIS PROPERTY IS ALMOST REPAIRED- PH: 901-646-6000

# %%
resolution_codes = service_requests['resolution_code']
resolution_code_meanings = service_requests['resolution_code_meaning']

resolution_meaning = list(zip(resolution_codes, resolution_code_meanings))


resolution_set = set(resolution_meaning)

for code, meaning in resolution_set:
  if(code == 'VOYC'):
    print(meaning)

# resolution_code_meanings = new_service_requests['RESOLUTION_CODE_MEANING']
# resolution_code_meanings.unique()
# Out:
# nan
# V.O. Yard/Vehicle

# %%
resolution_codes
# Out:
# 0                 NaN
# 1                 NaN
# 2        BACK TO MCSC
# 3        BACK TO MCSC
# 4                 NaN
#              ...
# 12107             NaN
# 12108             NaN
# 12109             NaN
# 12110             NaN
# 12111           CTCNT
# Name: RESOLUTION_CODE, Length: 12112, dtype: object

# %%
glossary = pd.read_csv('Code_Enforcement_Glossary_20240320.csv')

# %%
glossary_tuples = list(zip(glossary['Code'], glossary['Definition']))
glossary_tuples = set(glossary_tuples)
glossary_tuples
# Out:
# {('( R ) LA', 'ADMIN. Review- Legal action'),
#  ('8A', 'CD Final Notice Letter'),
#  ('ATSS1', 'Attempting to service summon 1'),
#  ('ATSS2', 'Attempting to service summon 2'),
#  ('ATSS3', 'Attempting to service summon 3'),
#  ('B-S', 'Board And Secure'),
#  ('B-S-NOTIFIED', 'Board And Secure Notified Contractor'),
#  ('BACK TO MCSC', 'Back To MCSC'),
#  ('BW', 'Bench warrant issued'),
#  ('CB-S', 'Close Board and Secure'),
#  ('CB-SO', 'Close Board and Secure by Owner'),
#  ('CCINO', 'Change of controlling inspector'),
#  ('CD', 'File assigned to condemnation'),
#  ('CDA', 'Demolished by ASP'),
#  ('CDC', 'Demolished by Condemnation'),
#  ('CDFM8', 'REC. Owner Demolish - FORM 8'),
#  ('CDNO', 'Condemnation Notice'),
#  ('CDO', 'Closed, Demolished by Owner'),
#  ('CDRCK', 'CD Recheck - to see if structures still qualifies'),
#  ('CNOH', 'Complaint - No one home'),
#  ('CO', 'Closed, Other'),
#  ('CODE-INSP', 'Assign to Code Enforcement Inspector'),
#  ('CR', 'Closed, Rehab'),
#  ('CTCNT', 'Court case continued'),
#  ('CTCNT2', 'Court case continued 2'),
#  ('CTCNT3', 'Court case continued 3'),
#  ('CTCNT4', 'Court case continued 4'),
#  ('CTCNT5', 'Court case continued 5'),
#  ('CTIME', 'Conference time entry(Field)'),
#  ('CTINS', 'Inspection prior to court'),
#  ('CVOAR', 'COMP. V.O. - Auto removed'),
#  ('CVOAT', 'COMP. V.O. Auto tow issued'),
#  ('CVOBD', 'COMP. V.O. BLDG. Demolished'),
#  ('CVOBR', 'COMP. V.O. BLDG. Repaired'),
#  ('CVOID', 'Closed Void'),
#  ('CVOM', 'COMP. V.O. - Miscellaneous'),
#  ('CVOYC', 'COMP. V.O. - Yard cleaned'),
#  ('DEMO-ASSIGNED', 'Assigned to demolition Contractor to be demolished'),
#  ('DISM', 'Case dismissed         Need further discussion'),
#  ('DMV', 'Demolition verified'),
#  ('DNO', 'Do not occupy - FORM 15'),
#  ('FFM11', 'Comply or Legal action - FORM 11'),
#  ('FINE', 'Fine assessed            Need further discussion'),
#  ('FM-7', 'Hearing missed - FORM 7'),
#  ('FM12', 'Not complying - FORM 12 and 12A'),
#  ('FM14', 'Legal Action - 15 DAYS - FORM 14'),
#  ('HD-CODE', 'Hearing date set for Code'),
#  ('HH', 'Hearing held - Personal visit'),
#  ('HHF', 'Hearing held in field'),
#  ('HHFM7', 'Hearing - result of FORM 7'),
#  ('HHL', 'Hearing held by letter'),
#  ('HHT', 'Hearing held by telephone'),
#  ('ID2', '2nd Intent to demolish letter'),
#  ('INSUF', 'Insufficient information'),
#  ('JA', 'Justified, Active already file'),
#  ('JAR', 'Justified, Active already revised'),
#  ('JT', 'Justified transfer'),
#  ('JV', 'Justified verbal'),
#  ('JW-DM', 'Justified, write-up demolition'),
#  ('JW-RH', 'Justified, write-up - Rehab'),
#  ('LD', 'REFERRAL COMPLAINT'),
#  ('LEGAL-HOLD', 'Legal Hold       Set to six months follow-up'),
#  ('MISNO', 'Miscellaneous'),
#  ('MLGW', 'MLGW CUT OFF NOTICE'),
#  ('MLGW-COMP', 'MLGW Disconnects Completed'),
#  ('NJ', 'Case not justified'),
#  ('NOH', 'No one home'),
#  ('NPA-ACTIVE', 'Keep the file open in the system Keeping the status NPA'),
#  ('NPA-CD',
#   'Property referred by the condemnation department to NPA removing the status CD and putting the status NPA'),
#  ('NPA-DISMISSED', 'NPA Dismissed'),
#  ('NPA-REFERRAL', 'Keep the file open in the system Keeping the status NPA'),
#  ('NPA-RT-CD', 'NPA Return to CD'),
#  ('NPASC', 'Inspection did not pass - Close    ?? Rename ??'),
#  ('NPASS', 'Inspection did not pass'),
#  ('NPF11', 'No progress - FORM 11'),
#  ('NPF11-1', nan),
#  ('NPF11-2', nan),
#  ('NPF11-3', nan),
#  ('NPF11-4', nan),
#  ('NPF11-COMP', 'No progress Form 11 Complete'),
#  ('NPL', 'No progress - Letter'),
#  ('NPM', 'No progress - Monitor'),
#  ('NPP', 'No progress - Personal visit'),
#  ('NPRAA', 'No progress - REC. A.D. Action'),
#  ('NPRCD', 'No progress - REC. Condemnation'),
#  ('NPRLA', 'No progress - REC. A.D. Legal action'),
#  ('NPT', 'No progress - Telephone'),
#  ('OCC', 'Order of condemnation letter'),
#  ('OTHER', 'Please see Resolution Summary'),
#  ('PS', 'CITATION ISSUED TO PROCESS SERVER'),
#  ('RCD', 'ADMIN. Review condemn'),
#  ('RCD - WS', 'ADMIN. Review, Condemn ASP - Send waiver'),
#  ('RCONT', 'ADMIN. Review, Continue'),
#  ('RCTAC', 'ADMIN. Review, Contact'),
#  ('RMONT', 'ADMIN. Review monitor'),
#  ('RTA', 'Return to active'),
#  ('RV', 'Revised'),
#  ('RVAC', 'ADMIN. Review vacate'),
#  ('RVSO1', 'Revise Start Over - 1  (JW-RH)'),
#  ('RVSO2', 'Revise Start Over - 2  (JW-DM)'),
#  ('SC', 'Condemnation show cause hearing letter'),
#  ('SO', 'Start over'),
#  ('SUMM', 'Summons issued'),
#  ('Shelby',
#   'Shelby County Owned Property. Please contact the Shelby County Land Bank at 901-222-2575 for further information.'),
#  ('Submit-NPA', "Referred to Patrick Dandridge's office"),
#  ('TAXLTR', 'Tax letter'),
#  ('TS', 'Title search requested (CD/INSPECTOR)'),
#  ('TS-COMPLETE', 'Title Search Completed'),
#  ('UC', 'Uncooperative'),
#  ('VNR', 'Vacate notice rescinded'),
#  ('VOAR', 'V.O. to remove auto'),
#  ('VOB', 'V.O. for accessory BLDG.'),
#  ('VOI', 'Vacated - Own initiative'),
#  ('VOM', 'V.O. for miscellaneous'),
#  ('VONP', 'No progress on V.O.'),
#  ('VONP2', 'No Progress 2 on VO'),
#  ('VOWP', 'Work progress on V.O.'),
#  ('VOWP2', 'Work progress 2 on VO'),
#  ('VOWP3', 'Work progress 3 on VO'),
#  ('VOWP4', 'Work progress 4 on VO'),
#  ('VOWP5', 'Work progress 5 on VO'),
#  ('VOYC', 'V.O. Yard/Vehicle'),
#  ('VP', 'Vacate notice posted'),
#  ('WPF11', 'Work Progress - FORM 11'),
#  ('WPO', 'Work progress - Observations'),
#  ('WPP', 'Work progress - Personal visit'),
#  ('WPT', 'Work progress - Telephone'),
#  ('WS', 'Waiver Sent')}

# %%
categories = new_service_requests['category'].unique()
categories


# count = 0
# for request in new_service_requests['CATEGORY']:
#     if request == 'Miscellaneous':
#         count += 1
        
# count
# Out:
# array(['Environmental Maintenance', 'Maintenance', 'Inspection-Vehicle',
#        'Others', 'Miscellaneous', 'Maintenance-Potholes',
#        'Inspection-Junky Yard', 'Weeds', 'Inspection-Structures',
#        'Cart Maintenance', 'Garbage', 'Inspection- Storage', 'Recycle',
#        'Cleanup', 'Service', 'Billing', 'Inspection-Vacant Violation',
#        'Storm Water', 'Inspection- Recreational', 'Maintenance-Alley'],
#       dtype=object)

# %%
coordinate_data = service_requests['location_1']
        
parsed_coordinates = []
        
for point in coordinate_data:
    if isinstance(point,float):
        continue
    
    parsed_coordinates.append((float(point.split()[1][1:]), float(point.split()[2][:-1])))
    
    
df = pd.DataFrame(parsed_coordinates, columns=['Longitude', 'Latitude'])
print(len(df))


USA = ((-124.72,  -66.95), (23.55, 50.06))

from datashader.utils import lnglat_to_meters as webm
x_range,y_range = [list(r) for r in webm(*USA)]

plot_width  = int(2000)
plot_height = int(plot_width*7.0/12)

background = "black"

from functools import partial
from datashader.utils import export_image
from datashader.colors import colormap_select, Greys9

export = partial(export_image, background = background, export_path="export")
cm = partial(colormap_select, reverse=(background!="black"))

cvs = ds.Canvas(plot_width, plot_height, *webm(*USA))
agg = cvs.points(df, 'Longitude', 'Latitude')

export(tf.shade(agg, cmap = cm(Greys9,0.25), how='linear'),"census_gray_linear")
# Out:
# 12083
# <xarray.Image (Latitude: 1166, Longitude: 2000)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * Longitude  (Longitude) float64 -1.388e+07 -1.388e+07 ... -7.454e+06
#   * Latitude   (Latitude) float64 2.7e+06 2.704e+06 ... 6.452e+06 6.455e+06

# %% [markdown]
# # DBSCAN

# %%
from matplotlib import pyplot as plt
from sklearn.neighbors import NearestNeighbors
from sklearn import metrics
from sklearn.cluster import DBSCAN
from collections import Counter

# %%
coordinate_data = service_requests['location_1']
        
coordinates = []
        
for point in coordinate_data:
    if isinstance(point,float):
        continue
    
    coordinates.append((float(point.split()[1][1:]), float(point.split()[2][:-1])))
    
coordinates = np.array(coordinates)

# %% [markdown]
# ### Plot Coordinates Before Clustering

# %%
x, y = coordinates.T
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### Finding Optimal eps Value

# %%
neighbors = NearestNeighbors(n_neighbors=50)
neighbors_fit = neighbors.fit(coordinates)
distances, indices = neighbors_fit.kneighbors(coordinates)

distances = np.sort(distances, axis=0)
distances = distances[:,1]

#Zoom in on curve
plt.xlim(11900, 12100)
plt.ylim(0, 0.0175)

plt.plot(distances)

# %% [markdown]
# ### Run DBSCAN Algorithm

# %%
Density_Scan = DBSCAN(eps=0.013, min_samples=50).fit(coordinates)
labels = Density_Scan.labels_

# Number of clusters, ignoring noise
noise_points = list(labels).count(-1)
cluster_amount = len(set(labels)) - (1 if -1 in labels else 0)

print("Estimated number of clusters: %d" % cluster_amount)
print("Estimated number of noise points: %d" % noise_points)
# Out:
# Estimated number of clusters: 5
# Estimated number of noise points: 163

# %%
cluster_labels = set(labels)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[Density_Scan.core_sample_indices_] = True

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(cluster_labels))]
for k, col in zip(cluster_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    # Displays points that are core samples
    xy = coordinates[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=6,
    )

    # Displays points that are not core samples 
    xy = coordinates[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=4,
    )

plt.title("DBSCAN Results")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.show()

# %% [markdown]
# ### Seperate Clusters

# %%
cluster_0 = []
cluster_1 = []
cluster_2 = []
cluster_3 = []
cluster_4 = []

index = 0

# Puts the index of a point into its respective cluster
for cluster_label in labels:
    if cluster_label == 0:
        cluster_0.append(index)
        
    if cluster_label == 1:
        cluster_1.append(index)
        
    if cluster_label == 2:
        cluster_2.append(index)
        
    if cluster_label == 3:
        cluster_3.append(index)
        
    if cluster_label == 4:
        cluster_4.append(index)
        
    index += 1 
    
print(len(cluster_0) + len(cluster_1) + len(cluster_2) + len(cluster_3) + len(cluster_4) + noise_points)

#cluster_0_parsed = df.iloc[cluster_0]
#display(cluster_0_parsed)
# Out:
# 12083

# %%
for tuples in new_classifier:
    for c in tuples:
    
        service_requests['category'].replace(c, new_classifier[tuples], inplace=True)

category = service_requests['category']
parsed_category = [] 

i = 0 
for point in coordinate_data:
    if isinstance(point,float):
        continue
        
    parsed_category.append(category[i])
    i += 1

# %%
cluster_0_category = []
cluster_1_category = []
cluster_2_category = []
cluster_3_category = []
cluster_4_category = []
cluster_5_category = []
cluster_6_category = []
cluster_7_category = []

# Counts occurences of category in Cluster 0!
for idx in cluster_0:
    cluster_0_category.append(parsed_category[idx])
    
zero_cat = dict(Counter(cluster_0_category))

# Counts occurences of category in Cluster 1!
for idx in cluster_1:
    cluster_1_category.append(parsed_category[idx])
    
one_cat = dict(Counter(cluster_1_category))

# Counts occurences of category in Cluster 2!
for idx in cluster_2:
    cluster_2_category.append(parsed_category[idx])
    
two_cat = dict(Counter(cluster_2_category))

# Counts occurences of category in Cluster 3!
for idx in cluster_3:
    cluster_3_category.append(parsed_category[idx])
    
three_cat = dict(Counter(cluster_3_category))

# Counts occurences of category in Cluster 4!
for idx in cluster_4:
    cluster_4_category.append(parsed_category[idx])
    
four_cat = dict(Counter(cluster_4_category))

list_of_dicts = [zero_cat, one_cat, two_cat, three_cat, four_cat]

# %%
d = 0 
for dictionary in list_of_dicts:
    #Sort clusters by number of requests
    dictionary = dict(sorted(dictionary.items(), key=lambda item: item[1]))
    
    #Find most frequent request in each cluster 
    max_category = max(dictionary, key=dictionary.get)
    print("\nCluster", d, ":\n")
    print(" Most frequent service request in cluster:", max_category, "\n")
    
    print(" Other Categories and how many times service was requested:")
    for category, requests in dictionary.items():
        print(f"     {category}: {requests}")
    
    d += 1
# Out:
# Cluster 0 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 436
#      Others: 584
#      Infrastructure Maintenance: 602
#      Environmental Maintenance: 1452
#      Miscellaneous: 1628
#      Inspections: 3775
#
# Cluster 1 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Infrastructure Maintenance: 84
#      Public Works: 84
#      Others: 87
#      Environmental Maintenance: 235
#      Miscellaneous: 256
#      Inspections: 554
#
# Cluster 2 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 76
#      Others: 98
#      Infrastructure Maintenance: 101
#      Environmental Maintenance: 214
#      Miscellaneous: 245
#      Inspections: 589
#
# Cluster 3 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 27
#      Infrastructure Maintenance: 38
#      Others: 38
#      Environmental Maintenance: 82
#      Miscellaneous: 91
#      Inspections: 193
#
# Cluster 4 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 20
#      Infrastructure Maintenance: 25
#      Others: 25
#      Environmental Maintenance: 54
#      Miscellaneous: 68
#      Inspections: 159

# %% [markdown]
# ## KMedoids for big cluster

# %%
X = np.asarray(cluster_0_parsed)
x, y = X.T
plt.scatter(x,y)

# %%
from sklearn_extra.cluster import KMedoids

k_medoids = KMedoids(n_clusters=4, random_state=0).fit(X)


k_medoids_labels = k_medoids.labels_

# Number of clusters, ignoring noise
k_noise_points = list(k_medoids_labels).count(-1)
cluster_amount = len(set(k_medoids_labels)) - (1 if -1 in k_medoids_labels else 0)

print("Estimated number of clusters: %d" % cluster_amount)
print("Estimated number of noise points: %d" % k_noise_points)
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 0

# %% [markdown]
# ## Combine Clustering Labels

# %%
print(k_medoids_labels)

mapping = {0:0, 1:5 , 2:6, 3:7}

mapped_k_medoids = np.array([mapping[label] for label in k_medoids_labels])
print(mapped_k_medoids)


cluster_0_indx = 0
for i in cluster_0:
  labels[i] = mapped_k_medoids[cluster_0_indx]
  cluster_0_indx += 1

print(set(labels))
# Out:
# [0 3 1 ... 2 3 1]
# [0 7 5 ... 6 7 5]
# {0, 1, 2, 3, 4, 5, 6, 7, -1}

# %%
plt.figure(figsize=(8,6))


cluster_labels = set(labels)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[Density_Scan.core_sample_indices_] = True

print(Density_Scan.core_sample_indices_)

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(cluster_labels))]
for k, col in zip(cluster_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = labels == k

    # Displays points that are core samples
    xy = coordinates[class_member_mask & core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=5,
    )

    # Displays points that are not core samples 
    xy = coordinates[class_member_mask & ~core_samples_mask]
    plt.plot(
        xy[:, 0],
        xy[:, 1],
        "o",
        markerfacecolor=tuple(col),
        markeredgecolor="k",
        markersize=4,
    )



# for i in range(k_medoids.n_clusters):
#     cluster_points = X[k_medoids.labels_ == i]
#     medoid = X[k_medoids.medoid_indices_[i]]
#     plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {i}')
#     plt.scatter(medoid[0], medoid[1], marker='*', color='black', s=200, label=f'Medoid {i}')
# Out:
# [    0     1     2 ... 12080 12081 12082]

# %%
cluster_0 = []
cluster_1 = []
cluster_2 = []
cluster_3 = []
cluster_4 = []
cluster_5 = []
cluster_6 = []
cluster_7 = []

index = 0

# Puts the index of a point into its respective cluster
for cluster_label in labels:
    if cluster_label == 0:
        cluster_0.append(index)
        
    if cluster_label == 1:
        cluster_1.append(index)
        
    if cluster_label == 2:
        cluster_2.append(index)
        
    if cluster_label == 3:
        cluster_3.append(index)
        
    if cluster_label == 4:
        cluster_4.append(index)
        
    if cluster_label == 5:
        cluster_5.append(index)
        
    if cluster_label == 6:
        cluster_6.append(index)
        
    if cluster_label == 7:
        cluster_7.append(index)
        
    index += 1

# %%
cluster_0_category = []
cluster_1_category = []
cluster_2_category = []
cluster_3_category = []
cluster_4_category = []
cluster_5_category = []
cluster_6_category = []
cluster_7_category = []

# Counts occurences of category in Cluster 0!
for idx in cluster_0:
    cluster_0_category.append(parsed_category[idx])
    
zero_cat = dict(Counter(cluster_0_category))

# Counts occurences of category in Cluster 1!
for idx in cluster_1:
    cluster_1_category.append(parsed_category[idx])
    
one_cat = dict(Counter(cluster_1_category))

# Counts occurences of category in Cluster 2!
for idx in cluster_2:
    cluster_2_category.append(parsed_category[idx])
    
two_cat = dict(Counter(cluster_2_category))

# Counts occurences of category in Cluster 3!
for idx in cluster_3:
    cluster_3_category.append(parsed_category[idx])
    
three_cat = dict(Counter(cluster_3_category))

# Counts occurences of category in Cluster 4!
for idx in cluster_4:
    cluster_4_category.append(parsed_category[idx])
    
four_cat = dict(Counter(cluster_4_category))

# Counts occurences of category in Cluster 4!
for idx in cluster_5:
    cluster_5_category.append(parsed_category[idx])
    
five_cat = dict(Counter(cluster_5_category))

# Counts occurences of category in Cluster 4!
for idx in cluster_6:
    cluster_6_category.append(parsed_category[idx])
    
six_cat = dict(Counter(cluster_6_category))

# Counts occurences of category in Cluster 4!
for idx in cluster_7:
    cluster_7_category.append(parsed_category[idx])
    
seven_cat = dict(Counter(cluster_7_category))

list_of_dicts = [zero_cat, one_cat, two_cat, three_cat, four_cat, five_cat, six_cat, seven_cat]

# %%
d = 0 
for dictionary in list_of_dicts:
    #Sort clusters by number of requests
    dictionary = dict(sorted(dictionary.items(), key=lambda item: item[1]))
    
    #Find most frequent request in each cluster 
    max_category = max(dictionary, key=dictionary.get)
    print("\nCluster", d, ":\n")
    print(" Most frequent service request in cluster:", max_category, "\n")
    
    print(" Other Categories and how many times service was requested:")
    for category, requests in dictionary.items():
        print(f"     {category}: {requests}")
    
    d += 1
# Out:
# Cluster 0 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Others: 123
#      Public Works: 126
#      Infrastructure Maintenance: 152
#      Environmental Maintenance: 358
#      Miscellaneous: 417
#      Inspections: 955
#
# Cluster 1 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Infrastructure Maintenance: 84
#      Public Works: 84
#      Others: 87
#      Environmental Maintenance: 235
#      Miscellaneous: 256
#      Inspections: 554
#
# Cluster 2 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 76
#      Others: 98
#      Infrastructure Maintenance: 101
#      Environmental Maintenance: 214
#      Miscellaneous: 245
#      Inspections: 589
#
# Cluster 3 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 27
#      Infrastructure Maintenance: 38
#      Others: 38
#      Environmental Maintenance: 82
#      Miscellaneous: 91
#      Inspections: 193
#
# Cluster 4 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 20
#      Infrastructure Maintenance: 25
#      Others: 25
#      Environmental Maintenance: 54
#      Miscellaneous: 68
#      Inspections: 159
#
# Cluster 5 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 77
#      Others: 94
#      Infrastructure Maintenance: 111
#      Environmental Maintenance: 284
#      Miscellaneous: 329
#      Inspections: 703
#
# Cluster 6 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 113
#      Others: 179
#      Infrastructure Maintenance: 195
#      Environmental Maintenance: 436
#      Miscellaneous: 470
#      Inspections: 1162
#
# Cluster 7 :
#
#  Most frequent service request in cluster: Inspections
#
#  Other Categories and how many times service was requested:
#      Public Works: 120
#      Infrastructure Maintenance: 144
#      Others: 188
#      Environmental Maintenance: 374
#      Miscellaneous: 412
#      Inspections: 955

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import BallTree
import plotly.express as px

longitude = coordinates[:, 0]
latitude = coordinates[:, 1]

long_dict = dict(enumerate(longitude))
lat_dict = dict(enumerate(latitude))


long_lat = {'Longitude': long_dict, 'Latitude': lat_dict}
long_lat_df = pd.DataFrame(data=long_lat)


coords = long_lat_df[["Longitude","Latitude"]]

distance_in_miles = 1
earth_radius_in_miles = 3958.8

radius = distance_in_miles / earth_radius_in_miles


tree = BallTree(np.radians(coords), leaf_size=1, metric='haversine')

neighbors = tree.query_radius( np.radians(coords), r=radius, count_only=True)
neighbor_dict = dict(enumerate(neighbors))

long_lat_n = {'Longitude': long_dict, 'Latitude': lat_dict, 'Neighbors': neighbor_dict}
long_lat__n_df = pd.DataFrame(data=long_lat_n)

fig = px.density_mapbox(long_lat__n_df, lat='Latitude', lon='Longitude', z='Neighbors', mapbox_style="open-street-map", 
                        opacity = 0.8, radius = 10)
fig.show()
# Out:
# <div>                            <div id="76b3d85a-8f38-405a-9f22-dc2b3318863c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76b3d85a-8f38-405a-9f22-dc2b3318863c")) {                    Plotly.newPlot(                        "76b3d85a-8f38-405a-9f22-dc2b3318863c",                        [{"coloraxis":"coloraxis","hovertemplate":"Neighbors=%{z}<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[35.147453143,35.096020007,35.089373996,35.174220984,35.021354014,35.05181439,35.083736999,35.255059998,35.123713019,35.124072016,35.21727413,35.132020994,35.156381989,35.151348988,35.10201202,35.062825994,35.104242989,35.043740987,35.196453983,35.210432523,35.214977881,35.228744007,35.135204088,35.198945,35.135147988,35.070936438,35.153056008,35.107780991,35.097812016,35.21342302,35.079735017,35.120044129,35.044169009,35.032378018,35.14161601,35.215036997,35.083309019,35.049753997,35.209739006,35.199143987,35.088176013,35.106329999,35.025833009,35.067681002,35.131714006,35.113576993,35.090838985,35.114013983,35.144739987,35.09884299,35.108448986,35.033630987,35.211049013,35.18118798,35.035893011,35.164363992,35.142378009,35.07151698,35.0297,35.092628982,35.18871099,35.209750992,35.167988997,35.152202982,35.101117,35.044962985,35.109972984,35.079373003,35.153762016,35.121100002,35.111353986,35.192237005,35.110281019,35.178885011,35.038647011,35.124940004,35.161694021,35.052775003,35.016585004,35.152202982,35.115561995,35.099279017,35.070745007,35.167791017,35.125358009,35.08898,35.166325986,35.02039898,35.054988998,35.17852003,35.110015983,35.102627,35.122727272,35.167035011,35.192626009,35.170591998,35.172997981,35.064295006,35.16036201,35.231529984,35.168148002,35.236605017,35.059633998,35.071351018,35.254935988,35.033751016,35.012214502,35.118155021,35.154316982,35.154496983,35.033528979,35.15938401,35.174479985,35.165659223,35.040352016,35.088299017,35.112067999,35.147141989,35.101235982,35.182317987,35.102515982,35.209382984,35.112730002,35.231012988,35.116041985,35.120592017,35.161118016,35.078562012,35.029418997,35.109305994,35.156183003,35.027896005,35.223756984,35.233182015,35.170663998,35.08019598,35.183055007,35.09532498,35.112615002,35.051756015,35.149571986,35.115226007,35.054000982,35.045322988,35.052351004,35.052993016,35.068686998,35.186199017,35.092103982,35.156286981,35.046321985,35.062127991,35.060334012,35.098144987,35.152675009,35.095543999,35.107526013,35.137915986,35.084669988,35.088952009,35.138741017,35.085153028,35.210761011,35.053029016,35.096973993,35.096391996,35.063959018,35.050599983,35.117135991,35.166333991,35.064956913,35.105471604,35.084453987,35.214202998,35.16165999,34.995251007,35.14316201,35.242844003,35.096268992,35.027333999,35.126635733,35.206966985,35.152759935,35.120060018,35.11020202,35.112992984,35.028178014,35.164599984,35.154091006,35.106975993,35.075975985,35.060287996,35.164966986,35.134311013,35.069231989,35.044307981,35.128969981,35.010380007,35.038041,35.090556012,35.18440902,35.103349981,35.167324983,35.067878983,35.164829984,35.109986018,35.070150017,35.027443005,35.008457995,35.150567002,35.02451902,35.005591006,35.100674017,35.141919979,35.166685989,35.059622885,35.152876007,35.022572994,35.010405991,35.162535019,35.128303997,35.068010998,35.116093995,35.06979102,35.164224014,35.044811985,35.087846981,35.045478011,35.171042986,35.169834986,35.007153016,35.101237993,35.179678986,35.055164013,35.015746017,35.104529396,35.197033004,35.065009983,35.115092986,35.178805005,35.17848402,35.230716018,35.208872988,35.111742991,35.049854999,35.095418983,35.146243994,35.167757992,35.107614987,35.084185011,35.111237017,35.184340335,35.036313277,35.140994995,35.114209443,35.094744994,35.102320013,35.028342006,35.22476298,35.110954002,35.005681992,3 ...

# %%
# Initialize a dictionary to store
#  indices for each cluster label
clusters = {i: [] for i in range(8)}
noise_points = []

# Iterate over the labels and store the indices in the respective cluster
for i, cluster_label in enumerate(labels):
    if cluster_label != -1:
        clusters[cluster_label].append(i)
    else:
        noise_points.append(i)

# Calculate the total number of points
total_points = sum(len(cluster) for cluster in clusters.values()) + len(noise_points)
print(total_points)

# Extract data for each cluster
cluster_data = {cluster_label: df.iloc[indices] for cluster_label, indices in clusters.items()}

# print(cluster_data.items())
for cluster_label, data in cluster_data.items():
    # print(cluster_label)
    # print(data)
    print(f"Cluster {cluster_label} data:")
#     #Sort clusters by number of requests
display(data)
# Out:
# 12083
# Cluster 0 data:
# Cluster 1 data:
# Cluster 2 data:
# Cluster 3 data:
# Cluster 4 data:
# Cluster 5 data:
# Cluster 6 data:
# Cluster 7 data:
#        Longitude   Latitude
# 1     -89.839880  35.096020
# 15    -89.809510  35.062826
# 16    -89.850356  35.104243
# 25    -89.848197  35.070936
# 28    -89.891167  35.097812
# ...          ...        ...
# 12063 -89.842744  35.075525
# 12065 -89.843565  35.045772
# 12069 -89.840168  35.029954
# 12074 -89.840845  35.057443
# 12080 -89.910058  35.093315
#
# [2193 rows x 2 columns]

# %% [markdown]
# ## Community & Neighborhood Boundaries

# %%
import geopandas as gpd
from shapely import wkt


boundaries = pd.read_csv('Community_Neighborhoods_Boundaries_20240425.csv')
display(boundaries)
polygons = boundaries['the_geom']
polygons.head()

load_polygons = [wkt.loads(polygon) for polygon in polygons]


gdf = gpd.GeoDataFrame(geometry=load_polygons)

gdf.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[166], line 5
#       1 import geopandas as gpd
#       2 from shapely import wkt
# ----> 5 boundaries = pd.read_csv('Community_Neighborhoods_Boundaries_20240425.csv')
#       6 display(boundaries)
#       7 polygons = boundaries['the_geom']
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Community_Neighborhoods_Boundaries_20240425.csv'

# %% [markdown]
# ## Resolution dates by clusters

# %%
print(service_requests['creation_date'])
print(len(set(service_requests['close_date'])))
print(len(set(service_requests['followup_date'])))
print(len(set(service_requests['last_update_date'])))
print(len(set(service_requests['last_modified_date'])))



# for item in service_requests['close_date']:
  # print(item)
# for data in cluster_data.items():
#   print(data)

# %%
d
